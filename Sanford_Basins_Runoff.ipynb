# %% [markdown]
# ## Code for Runoff analysis over CONUS404 based estimation in comparison with USGS-CAMELS datasets
#
# ### Author: Miguel Diaz

# %% [markdown]
# #### **Libraries**

# %% [markdown]
# !pip install absl-py apache-beam xarray xarray-beam earthengine-api geemap pyproj geopandas pandas numpy sparse hvplot holoviews dask cf-xarray geoviews pynhd hydrofunctions intake cartopy shapely matplotlib contextily scipy rasterio requests IPython
# !pip install notebook
# !earthengine authenticate
# !pip install dask[distributed]
# !pip install bokeh
# !pip install xee
# !pip install datashader
#
# !pip install zarr
# !pip install fsspec gcsfs s3fs
# !pip install --upgrade intake
# !pip install zarr intake intake-xarray fsspec s3fs gcsfs
# !pip install --upgrade intake intake-xarray zarr
# !pip install metpy
#
# !pip install --upgrade xarray metpy
# !pip install scikit-learn
# !pip install apache-beam
# !pip install cf_xarray

# %%
import logging
import os
import time
import warnings
import webbrowser

# Data handling and computation
import numpy as np
import pandas as pd
import xarray as xr
import cf_xarray
import dask
import dask.array as da
from dask import delayed
from dask.distributed import Client
import sparse

# Scientific libraries
import pyproj
from scipy.stats import linregress, gumbel_r

# GIS and remote sensing
import geopandas as gpd
import geemap
import ee
import xarray_beam as xbeam
import apache_beam as beam
import xee
import zarr

# Mapping and visualization
import hvplot.pandas
import hvplot.xarray
import holoviews as hv
from holoviews.operation.datashader import rasterize
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import contextily as ctx
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import plotly.express as px

# Geospatial libraries
from shapely.geometry import Polygon
from rasterio.enums import Resampling

# Hydrology and water data
from pynhd import NLDI, WaterData
import hydrofunctions as hf

# Data intake and registry
import intake
print(intake.registry)

# Meteorology and weather data
from metpy.units import units
import metpy  # Ensure this is imported to extend xarray

# Web and API requests
import requests
from IPython.display import HTML

# ABSL (Google's command-line flags and app framework)
from absl import app, flags

# Ensure inline plotting for Jupyter notebooks
# %matplotlib inline
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4a856adb-f69b-46b8-8c1c-d15dc7abb2ec'>
#   <div id="cf1c0692-ecc1-4a7d-822d-20bd5be9bf90" data-root-id="4a856adb-f69b-46b8-8c1c-d15dc7abb2ec" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"69c51208-b642-4c49-9f45-99be0cbda8da":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4a856adb-f69b-46b8-8c1c-d15dc7abb2ec"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8f954e5c-63ed-44ee-accb-b8e74107c4a2","attributes":{"plot_id":"4a856adb-f69b-46b8-8c1c-d15dc7abb2ec","comm_id":"6f3b638a6d36419ea2421395002cb500","client_comm_id":"f2587f6bd58242c7b512616147636c5f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"69c51208-b642-4c49-9f45-99be0cbda8da","roots":{"4a856adb-f69b-46b8-8c1c-d15dc7abb2ec":"cf1c0692-ecc1-4a7d-822d-20bd5be9bf90"},"root_ids":["4a856adb-f69b-46b8-8c1c-d15dc7abb2ec"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <Intake driver registry>

# %% [markdown]
# #### **CONUS 404 - SOURCES**

# %% [markdown]
# This section contains notebooks that demonstrate how to access and perform basic data manipulation for the [CONUS404 dataset](https://doi.org/10.5066/P9PHPK4F). The examples can also be applied to the [CONUS404 bias-adjusted dataset](https://doi.org/10.5066/P9JE61P7).

# %% [markdown]
# In the CONUS404 intake sub-catalog (see [here](../dataset_catalog/README.md) for an explainer of our intake data catalog), you will see entries for four CONUS404 datasets: `conus404-hourly`, `conus404-daily`, `conus404-monthly`, and `conus404-daily-diagnostic` data, as well as two CONUS404 bias-adjusted datasets: `conus404-hourly-ba`, `conus404-daily-ba`. Each of these datasets is duplicated in up to three different storage locations (as the [intake catalog section](../dataset_catalog/README.md) also describes).

# %% [markdown]
# In the CONUS404 intake sub-catalog (see [here](../dataset_catalog/README.md) for an explainer of our intake data catalog), you will see entries for:
# - four CONUS404 datasets: `conus404-hourly`, `conus404-daily`, `conus404-monthly`, and `conus404-daily-diagnostic` data
# - two CONUS404 bias-adjusted datasets: `conus404-hourly-ba`, `conus404-daily-ba`
# - two CONUS404 PGW datasets: `conus404-pgw-hourly` and `conus404-pgw-daily-diagnostic`

# %% [markdown]
# #### **Dask client with specified number of workers**

# %%
client = Client(n_workers=4)  
client
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# C:\Users\adi10136\AppData\Local\anaconda3\envs\CONUS404_test\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 56006 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:56009' processes=4 threads=32, memory=127.69 GiB>

# %%
import pandas as pd

# File paths
sanford_file = r"C:\Users\adi10136\OneDrive - Iowa State University\Desktop\CONUS404\ET Sanford\ET_Mean_Sanford_Agreed_Basins\AET_Basins_Mean_Values.csv"
conus404_file = r"C:\Users\adi10136\OneDrive - Iowa State University\Desktop\CONUS404\ET_WaterYears\AET_mean_Basins_CONUS404\ET_Basins_Mean_Values.csv"

# Load the CSV files
sanford_df = pd.read_csv(sanford_file)
conus404_df = pd.read_csv(conus404_file)

# Display first few rows
display(sanford_df.head())
display(conus404_df.head())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       name    AET_1990    AET_1991    AET_1992    AET_1993    AET_1994  \
# 0  1013500  532.240341  507.776588  535.722459  539.077791  565.502197
# 1  1019000  567.941718  582.810206  511.858339  486.392273  502.745313
# 2  1022500  569.082703  594.823793  492.098908  469.906591  509.816766
# 3  1030500  567.746502  532.820693  500.170837  510.349288  524.644646
# 4  1031500  579.718110  555.205357  499.591072  510.097644  548.800909
#
#      AET_1995    AET_1996    AET_1997    AET_1998  ...    AET_2000  \
# 0  482.285055  566.518196  523.279233  563.964709  ...  537.297215
# 1  517.294172  550.425525  542.522675  534.586589  ...  520.603610
# 2  511.827485  546.341557  520.660206  522.562560  ...  502.030355
# 3  484.188340  566.161814  533.798302  547.532335  ...  522.492560
# 4  465.343476  571.734233  534.114904  578.778529  ...  528.061480
#
#      AET_2001    AET_2002    AET_2003    AET_2004    AET_2005    AET_2006  \
# 0  508.036718  514.742219  564.394825  571.197801  562.928791  590.108365
# 1  478.210596  530.352665  526.827658  563.399872  603.767711  645.874811
# 2  469.466367  546.232928  517.376626  549.466122  563.798092  628.977870
# 3  488.804965  519.639529  550.728153  545.936762  577.533433  618.855820
# 4  502.142351  508.331367  543.141734  560.314031  593.353146  615.236319
#
#      AET_2007    AET_2008    AET_2009
# 0  541.385195  581.603163  555.641039
# 1  527.944763  578.211589  585.123058
# 2  544.564227  569.853500  585.333294
# 3  526.947449  571.365293  557.937971
# 4  522.362770  574.702154  562.149587
#
# [5 rows x 21 columns]
#       name     ET_1990     ET_1991     ET_1992     ET_1993     ET_1994  \
# 0  1013500  495.528522  512.796539  463.514122  487.558458  504.996250
# 1  1019000  499.585391  508.509752  421.748681  446.790894  480.256419
# 2  1022500  535.796254  560.605325  480.729019  505.535349  519.688975
# 3  1030500  542.833077  558.592781  484.850538  519.901025  529.423530
# 4  1031500  527.025566  552.803853  486.754495  514.397505  520.609899
#
#       ET_1995     ET_1996     ET_1997     ET_1998  ...     ET_2000  \
# 0  516.737636  463.709772  459.100789  482.126589  ...  477.541695
# 1  471.587569  457.372453  441.357433  468.003882  ...  460.994583
# 2  525.732224  494.877831  497.125226  520.270494  ...  504.111010
# 3  534.289118  499.099935  507.452618  528.592844  ...  508.964262
# 4  523.494781  512.750708  515.699722  537.828460  ...  509.612876
#
#       ET_2001     ET_2002     ET_2003     ET_2004     ET_2005     ET_2006  \
# 0  521.729294  502.856030  471.002144  485.324483  507.062311  521.457250
# 1  448.315687  476.387563  448.358631  448.451536  479.129280  496.595954
# 2  518.397766  536.849804  502.146776  492.854907  517.617510  532.765595
# 3  534.171812  545.085634  500.798790  510.233407  542.172768  548.714729
# 4  532.145247  548.136173  497.905593  502.271921  536.402295  540.497048
#
#       ET_2007     ET_2008     ET_2009
# 0  490.907687  480.312386  457.177166
# 1  464.294189  445.773821  441.038802
# 2  519.859560  500.135492  476.573745
# 3  517.182321  497.271122  492.144484
# 4  512.987179  509.845377  481.151956
#
# [5 rows x 21 columns]

# %%
# Merge the DataFrames on Gage_ID (OBJECTID or other unique field)
aligned_data = pd.merge(
    sanford_df,
    conus404_df,
    on="name",  # Change this if a different ID field is needed
    how="inner"
)

# Rename columns for clarity
aligned_data.rename(columns=lambda x: x.replace("AET_", "Sanford_").replace("ET_", "CONUS404_"), inplace=True)

# Drop rows with NaN values
aligned_data = aligned_data.dropna()

# Display first few rows
display(aligned_data.head())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       name  Sanford_1990  Sanford_1991  Sanford_1992  Sanford_1993  \
# 0  1013500    532.240341    507.776588    535.722459    539.077791
# 1  1019000    567.941718    582.810206    511.858339    486.392273
# 2  1022500    569.082703    594.823793    492.098908    469.906591
# 3  1030500    567.746502    532.820693    500.170837    510.349288
# 4  1031500    579.718110    555.205357    499.591072    510.097644
#
#    Sanford_1994  Sanford_1995  Sanford_1996  Sanford_1997  Sanford_1998  ...  \
# 0    565.502197    482.285055    566.518196    523.279233    563.964709  ...
# 1    502.745313    517.294172    550.425525    542.522675    534.586589  ...
# 2    509.816766    511.827485    546.341557    520.660206    522.562560  ...
# 3    524.644646    484.188340    566.161814    533.798302    547.532335  ...
# 4    548.800909    465.343476    571.734233    534.114904    578.778529  ...
#
#    CONUS404_2000  CONUS404_2001  CONUS404_2002  CONUS404_2003  CONUS404_2004  \
# 0     477.541695     521.729294     502.856030     471.002144     485.324483
# 1     460.994583     448.315687     476.387563     448.358631     448.451536
# 2     504.111010     518.397766     536.849804     502.146776     492.854907
# 3     508.964262     534.171812     545.085634     500.798790     510.233407
# 4     509.612876     532.145247     548.136173     497.905593     502.271921
#
#    CONUS404_2005  CONUS404_2006  CONUS404_2007  CONUS404_2008  CONUS404_2009
# 0     507.062311     521.457250     490.907687     480.312386     457.177166
# 1     479.129280     496.595954     464.294189     445.773821     441.038802
# 2     517.617510     532.765595     519.859560     500.135492     476.573745
# 3     542.172768     548.714729     517.182321     497.271122     492.144484
# 4     536.402295     540.497048     512.987179     509.845377     481.151956
#
# [5 rows x 41 columns]

# %%
# Define functions for Bias (BA) and RMSE
def calculate_bias(true_values, predicted_values):
    """Calculate Bias (Systematic Error)."""
    return np.mean(predicted_values - true_values)

def calculate_rmse(true_values, predicted_values):
    """Calculate Root Mean Square Error (RMSE)."""
    return np.sqrt(np.mean((predicted_values - true_values) ** 2))

# Compute Bias and RMSE for each Gage_ID
results = []
for gage_id, group in aligned_data.groupby("name"):
    true_values = group.filter(like="Sanford_").values.flatten()
    predicted_values = group.filter(like="CONUS404_").values.flatten()

    ba = calculate_bias(true_values, predicted_values)
    rmse = calculate_rmse(true_values, predicted_values)

    results.append({"Gage_ID": gage_id, "Bias (BA)": ba, "RMSE": rmse})

# Convert results to DataFrame and save
results_df = pd.DataFrame(results)
results_df.to_csv("AET_BE_RMSE_Sanford-CONUS404.csv", index=False)

# Display results
display(results_df.head())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Gage_ID  Bias (BA)       RMSE
# 0  1013500 -52.805331  65.574252
# 1  1019000 -80.406154  88.265015
# 2  1022500 -23.470314  45.715613
# 3  1030500 -16.553470  40.406543
# 4  1031500 -24.925571  45.066570

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import os

# Create output folder for scatter plots
output_folder = "Sanford_Scatter_Plots"
os.makedirs(output_folder, exist_ok=True)

# Function to create scatter plots with regression
def plot_scatter_with_regression(data, gage_id, output_folder):
    """Generate scatter plot for a specific Gage_ID."""
    gage_data = data[data["name"] == gage_id]

    # Extract X (Sanford ET) and Y (CONUS404 ET)
    X = gage_data.filter(like="Sanford_").values.flatten().reshape(-1, 1)
    Y = gage_data.filter(like="CONUS404_").values.flatten()

    if len(X) > 1:  # Ensure enough data points
        model = LinearRegression()
        model.fit(X, Y)
        Y_pred = model.predict(X)
        r_squared = model.score(X, Y)
        slope = model.coef_[0]

        # Plot Scatter with Regression
        plt.figure(figsize=(8, 6))
        plt.scatter(X, Y, color="blue", label="Data points")
        plt.plot(X, Y_pred, color="red", label=f"Linear Fit (y={slope:.2f}x + {model.intercept_:.2f})")
        plt.xlabel("Sanford AET (mm)")
        plt.ylabel("CONUS404 AET (mm)")
        plt.title(f"Gage {gage_id}: Scatter Plot")
        plt.legend()
        plt.grid(True)
        plt.text(0.05, 0.95, f"R² = {r_squared:.2f}", transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

        # Save plot
        filename = os.path.join(output_folder, f"Gage_{gage_id}_scatter.png")
        plt.savefig(filename, format="png")
        plt.close()
        print(f"Scatter plot saved for Gage ID: {gage_id} at {filename}")

# Loop through each Gage_ID and generate scatter plots
for gage_id in aligned_data["name"].unique():
    plot_scatter_with_regression(aligned_data, gage_id, output_folder)

print("✅ Scatter plots generated and saved in:", output_folder)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Scatter plot saved for Gage ID: 1013500 at Sanford_Scatter_Plots\Gage_1013500_scatter.png
# Scatter plot saved for Gage ID: 1019000 at Sanford_Scatter_Plots\Gage_1019000_scatter.png
# Scatter plot saved for Gage ID: 1022500 at Sanford_Scatter_Plots\Gage_1022500_scatter.png
# Scatter plot saved for Gage ID: 1030500 at Sanford_Scatter_Plots\Gage_1030500_scatter.png
# Scatter plot saved for Gage ID: 1031500 at Sanford_Scatter_Plots\Gage_1031500_scatter.png
# Scatter plot saved for Gage ID: 1038000 at Sanford_Scatter_Plots\Gage_1038000_scatter.png
# Scatter plot saved for Gage ID: 1047000 at Sanford_Scatter_Plots\Gage_1047000_scatter.png
# Scatter plot saved for Gage ID: 1052500 at Sanford_Scatter_Plots\Gage_1052500_scatter.png
# Scatter plot saved for Gage ID: 1054200 at Sanford_Scatter_Plots\Gage_1054200_scatter.png
# Scatter plot saved for Gage ID: 1055000 at Sanford_Scatter_Plots\Gage_1055000_scatter.png
# Scatter plot saved for Gage ID: 1057000 at Sanford_Scatter_Plots\Gage_1057000_scatter.png
# Scatter plot saved for Gage ID: 1064500 at Sanford_Scatter_Plots\Gage_1064500_scatter.png
# Scatter plot saved for Gage ID: 1073000 at Sanford_Scatter_Plots\Gage_1073000_scatter.png
# Scatter plot saved for Gage ID: 1073500 at Sanford_Scatter_Plots\Gage_1073500_scatter.png
# Scatter plot saved for Gage ID: 1078000 at Sanford_Scatter_Plots\Gage_1078000_scatter.png
# Scatter plot saved for Gage ID: 1094500 at Sanford_Scatter_Plots\Gage_1094500_scatter.png
# Scatter plot saved for Gage ID: 1096000 at Sanford_Scatter_Plots\Gage_1096000_scatter.png
# Scatter plot saved for Gage ID: 1097000 at Sanford_Scatter_Plots\Gage_1097000_scatter.png
# Scatter plot saved for Gage ID: 1102000 at Sanford_Scatter_Plots\Gage_1102000_scatter.png
# Scatter plot saved for Gage ID: 1104500 at Sanford_Scatter_Plots\Gage_1104500_scatter.png
# Scatter plot saved for Gage ID: 1109000 at Sanford_Scatter_Plots\Gage_1109000_scatter.png
# Scatter plot saved for Gage ID: 1109060 at Sanford_Scatter_Plots\Gage_1109060_scatter.png
# Scatter plot saved for Gage ID: 1111500 at Sanford_Scatter_Plots\Gage_1111500_scatter.png
# Scatter plot saved for Gage ID: 1116000 at Sanford_Scatter_Plots\Gage_1116000_scatter.png
# Scatter plot saved for Gage ID: 1116500 at Sanford_Scatter_Plots\Gage_1116500_scatter.png
# Scatter plot saved for Gage ID: 1118300 at Sanford_Scatter_Plots\Gage_1118300_scatter.png
# Scatter plot saved for Gage ID: 1118500 at Sanford_Scatter_Plots\Gage_1118500_scatter.png
# Scatter plot saved for Gage ID: 1119500 at Sanford_Scatter_Plots\Gage_1119500_scatter.png
# Scatter plot saved for Gage ID: 1121000 at Sanford_Scatter_Plots\Gage_1121000_scatter.png
# Scatter plot saved for Gage ID: 1123000 at Sanford_Scatter_Plots\Gage_1123000_scatter.png
# Scatter plot saved for Gage ID: 1127500 at Sanford_Scatter_Plots\Gage_1127500_scatter.png
# Scatter plot saved for Gage ID: 1129200 at Sanford_Scatter_Plots\Gage_1129200_scatter.png
# Scatter plot saved for Gage ID: 1134500 at Sanford_Scatter_Plots\Gage_1134500_scatter.png
# Scatter plot saved for Gage ID: 1137500 at Sanford_Scatter_Plots\Gage_1137500_scatter.png
# Scatter plot saved for Gage ID: 1139000 at Sanford_Scatter_Plots\Gage_1139000_scatter.png
# Scatter plot saved for Gage ID: 1139800 at Sanford_Scatter_Plots\Gage_1139800_scatter.png
# Scatter plot saved for Gage ID: 1142500 at Sanford_Scatter_Plots\Gage_1142500_scatter.png
# Scatter plot saved for Gage ID: 1144000 at Sanford_Scatter_Plots\Gage_1144000_scatter.png
# Scatter plot saved for Gage ID: 1151500 at Sanford_Scatter_Plots\Gage_1151500_scatter.png
# Scatter plot saved for Gage ID: 1152500 at Sanford_Scatter_Plots\Gage_1152500_scatter.png
# Scatter plot saved for Gage ID: 1162500 at Sanford_Scatter_Plots\Gage_1162500_scatter.png
# Scatter plot saved for Gage ID: 1166500 at Sanford_Scatter_Plots\Gage_1166500_scatter.png
# Scatter plot saved for Gage ID: 1168500 at Sanford_Scatter_Plots\Gage_1168500_scatter.png
# Scatter plot saved for Gage ID: 1169000 at Sanford_Scatter_Plots\Gage_1169000_scatter.png
# Scatter plot saved for Gage ID: 1170100 at Sanford_Scatter_Plots\Gage_1170100_scatter.png
# Scatter plot saved for Gage ID: 1171500 at Sanford_Scatter_Plots\Gage_1171500_scatter.png
# Scatter plot saved for Gage ID: 1174500 at Sanford_Scatter_Plots\Gage_1174500_scatter.png
# Scatter plot saved for Gage ID: 1176000 at Sanford_Scatter_Plots\Gage_1176000_scatter.png
# Scatter plot saved for Gage ID: 1181000 at Sanford_Scatter_Plots\Gage_1181000_scatter.png
# Scatter plot saved for Gage ID: 1185500 at Sanford_Scatter_Plots\Gage_1185500_scatter.png
# Scatter plot saved for Gage ID: 1186000 at Sanford_Scatter_Plots\Gage_1186000_scatter.png
# Scatter plot saved for Gage ID: 1186500 at Sanford_Scatter_Plots\Gage_1186500_scatter.png
# Scatter plot saved for Gage ID: 1187300 at Sanford_Scatter_Plots\Gage_1187300_scatter.png
# Scatter plot saved for Gage ID: 1193500 at Sanford_Scatter_Plots\Gage_1193500_scatter.png
# Scatter plot saved for Gage ID: 1195100 at Sanford_Scatter_Plots\Gage_1195100_scatter.png
# Scatter plot saved for Gage ID: 1196500 at Sanford_Scatter_Plots\Gage_1196500_scatter.png
# Scatter plot saved for Gage ID: 1197000 at Sanford_Scatter_Plots\Gage_1197000_scatter.png
# Scatter plot saved for Gage ID: 1197500 at Sanford_Scatter_Plots\Gage_1197500_scatter.png
# Scatter plot saved for Gage ID: 1204000 at Sanford_Scatter_Plots\Gage_1204000_scatter.png
# Scatter plot saved for Gage ID: 1208500 at Sanford_Scatter_Plots\Gage_1208500_scatter.png
# Scatter plot saved for Gage ID: 1315000 at Sanford_Scatter_Plots\Gage_1315000_scatter.png
# Scatter plot saved for Gage ID: 1331500 at Sanford_Scatter_Plots\Gage_1331500_scatter.png
# Scatter plot saved for Gage ID: 1333000 at Sanford_Scatter_Plots\Gage_1333000_scatter.png
# Scatter plot saved for Gage ID: 1334000 at Sanford_Scatter_Plots\Gage_1334000_scatter.png
# Scatter plot saved for Gage ID: 1336000 at Sanford_Scatter_Plots\Gage_1336000_scatter.png
# Scatter plot saved for Gage ID: 1350000 at Sanford_Scatter_Plots\Gage_1350000_scatter.png
# Scatter plot saved for Gage ID: 1350080 at Sanford_Scatter_Plots\Gage_1350080_scatter.png
# Scatter plot saved for Gage ID: 1350140 at Sanford_Scatter_Plots\Gage_1350140_scatter.png
# Scatter plot saved for Gage ID: 1365000 at Sanford_Scatter_Plots\Gage_1365000_scatter.png
# Scatter plot saved for Gage ID: 1367500 at Sanford_Scatter_Plots\Gage_1367500_scatter.png
# Scatter plot saved for Gage ID: 1372500 at Sanford_Scatter_Plots\Gage_1372500_scatter.png
# Scatter plot saved for Gage ID: 1388000 at Sanford_Scatter_Plots\Gage_1388000_scatter.png
# Scatter plot saved for Gage ID: 1388500 at Sanford_Scatter_Plots\Gage_1388500_scatter.png
# Scatter plot saved for Gage ID: 1391500 at Sanford_Scatter_Plots\Gage_1391500_scatter.png
# Scatter plot saved for Gage ID: 1395000 at Sanford_Scatter_Plots\Gage_1395000_scatter.png
# Scatter plot saved for Gage ID: 1396800 at Sanford_Scatter_Plots\Gage_1396800_scatter.png
# Scatter plot saved for Gage ID: 1397000 at Sanford_Scatter_Plots\Gage_1397000_scatter.png
# Scatter plot saved for Gage ID: 1400000 at Sanford_Scatter_Plots\Gage_1400000_scatter.png
# Scatter plot saved for Gage ID: 1401000 at Sanford_Scatter_Plots\Gage_1401000_scatter.png
# Scatter plot saved for Gage ID: 1402000 at Sanford_Scatter_Plots\Gage_1402000_scatter.png
# Scatter plot saved for Gage ID: 1405400 at Sanford_Scatter_Plots\Gage_1405400_scatter.png
# Scatter plot saved for Gage ID: 1408000 at Sanford_Scatter_Plots\Gage_1408000_scatter.png
# Scatter plot saved for Gage ID: 1408500 at Sanford_Scatter_Plots\Gage_1408500_scatter.png
# Scatter plot saved for Gage ID: 1409400 at Sanford_Scatter_Plots\Gage_1409400_scatter.png
# Scatter plot saved for Gage ID: 1410000 at Sanford_Scatter_Plots\Gage_1410000_scatter.png
# Scatter plot saved for Gage ID: 1411000 at Sanford_Scatter_Plots\Gage_1411000_scatter.png
# Scatter plot saved for Gage ID: 1411300 at Sanford_Scatter_Plots\Gage_1411300_scatter.png
# Scatter plot saved for Gage ID: 1411500 at Sanford_Scatter_Plots\Gage_1411500_scatter.png
# Scatter plot saved for Gage ID: 1413500 at Sanford_Scatter_Plots\Gage_1413500_scatter.png
# Scatter plot saved for Gage ID: 1414500 at Sanford_Scatter_Plots\Gage_1414500_scatter.png
# Scatter plot saved for Gage ID: 1415000 at Sanford_Scatter_Plots\Gage_1415000_scatter.png
# Scatter plot saved for Gage ID: 1420500 at Sanford_Scatter_Plots\Gage_1420500_scatter.png
# Scatter plot saved for Gage ID: 1423000 at Sanford_Scatter_Plots\Gage_1423000_scatter.png
# Scatter plot saved for Gage ID: 1429000 at Sanford_Scatter_Plots\Gage_1429000_scatter.png
# Scatter plot saved for Gage ID: 1429500 at Sanford_Scatter_Plots\Gage_1429500_scatter.png
# Scatter plot saved for Gage ID: 1431500 at Sanford_Scatter_Plots\Gage_1431500_scatter.png
# Scatter plot saved for Gage ID: 1434025 at Sanford_Scatter_Plots\Gage_1434025_scatter.png
# Scatter plot saved for Gage ID: 1435000 at Sanford_Scatter_Plots\Gage_1435000_scatter.png
# Scatter plot saved for Gage ID: 1439500 at Sanford_Scatter_Plots\Gage_1439500_scatter.png
# Scatter plot saved for Gage ID: 1440000 at Sanford_Scatter_Plots\Gage_1440000_scatter.png
# Scatter plot saved for Gage ID: 1440400 at Sanford_Scatter_Plots\Gage_1440400_scatter.png
# Scatter plot saved for Gage ID: 1442500 at Sanford_Scatter_Plots\Gage_1442500_scatter.png
# Scatter plot saved for Gage ID: 1445500 at Sanford_Scatter_Plots\Gage_1445500_scatter.png
# Scatter plot saved for Gage ID: 1447500 at Sanford_Scatter_Plots\Gage_1447500_scatter.png
# Scatter plot saved for Gage ID: 1447720 at Sanford_Scatter_Plots\Gage_1447720_scatter.png
# Scatter plot saved for Gage ID: 1449360 at Sanford_Scatter_Plots\Gage_1449360_scatter.png
# Scatter plot saved for Gage ID: 1450500 at Sanford_Scatter_Plots\Gage_1450500_scatter.png
# Scatter plot saved for Gage ID: 1451500 at Sanford_Scatter_Plots\Gage_1451500_scatter.png
# Scatter plot saved for Gage ID: 1451800 at Sanford_Scatter_Plots\Gage_1451800_scatter.png
# Scatter plot saved for Gage ID: 1452000 at Sanford_Scatter_Plots\Gage_1452000_scatter.png
# Scatter plot saved for Gage ID: 1452500 at Sanford_Scatter_Plots\Gage_1452500_scatter.png
# Scatter plot saved for Gage ID: 1457000 at Sanford_Scatter_Plots\Gage_1457000_scatter.png
# Scatter plot saved for Gage ID: 1464000 at Sanford_Scatter_Plots\Gage_1464000_scatter.png
# Scatter plot saved for Gage ID: 1464500 at Sanford_Scatter_Plots\Gage_1464500_scatter.png
# Scatter plot saved for Gage ID: 1467000 at Sanford_Scatter_Plots\Gage_1467000_scatter.png
# Scatter plot saved for Gage ID: 1467048 at Sanford_Scatter_Plots\Gage_1467048_scatter.png
# Scatter plot saved for Gage ID: 1469500 at Sanford_Scatter_Plots\Gage_1469500_scatter.png
# Scatter plot saved for Gage ID: 1470500 at Sanford_Scatter_Plots\Gage_1470500_scatter.png
# Scatter plot saved for Gage ID: 1472157 at Sanford_Scatter_Plots\Gage_1472157_scatter.png
# Scatter plot saved for Gage ID: 1473000 at Sanford_Scatter_Plots\Gage_1473000_scatter.png
# Scatter plot saved for Gage ID: 1474000 at Sanford_Scatter_Plots\Gage_1474000_scatter.png
# Scatter plot saved for Gage ID: 1477000 at Sanford_Scatter_Plots\Gage_1477000_scatter.png
# Scatter plot saved for Gage ID: 1479000 at Sanford_Scatter_Plots\Gage_1479000_scatter.png
# Scatter plot saved for Gage ID: 1480000 at Sanford_Scatter_Plots\Gage_1480000_scatter.png
# Scatter plot saved for Gage ID: 1480500 at Sanford_Scatter_Plots\Gage_1480500_scatter.png
# Scatter plot saved for Gage ID: 1484100 at Sanford_Scatter_Plots\Gage_1484100_scatter.png
# Scatter plot saved for Gage ID: 1485500 at Sanford_Scatter_Plots\Gage_1485500_scatter.png
# Scatter plot saved for Gage ID: 1487000 at Sanford_Scatter_Plots\Gage_1487000_scatter.png
# Scatter plot saved for Gage ID: 1491000 at Sanford_Scatter_Plots\Gage_1491000_scatter.png
# Scatter plot saved for Gage ID: 1495000 at Sanford_Scatter_Plots\Gage_1495000_scatter.png
# Scatter plot saved for Gage ID: 1500000 at Sanford_Scatter_Plots\Gage_1500000_scatter.png
# Scatter plot saved for Gage ID: 1509000 at Sanford_Scatter_Plots\Gage_1509000_scatter.png
# Scatter plot saved for Gage ID: 1510000 at Sanford_Scatter_Plots\Gage_1510000_scatter.png
# Scatter plot saved for Gage ID: 1516500 at Sanford_Scatter_Plots\Gage_1516500_scatter.png
# Scatter plot saved for Gage ID: 1518862 at Sanford_Scatter_Plots\Gage_1518862_scatter.png
# Scatter plot saved for Gage ID: 1523500 at Sanford_Scatter_Plots\Gage_1523500_scatter.png
# Scatter plot saved for Gage ID: 1524500 at Sanford_Scatter_Plots\Gage_1524500_scatter.png
# Scatter plot saved for Gage ID: 1532000 at Sanford_Scatter_Plots\Gage_1532000_scatter.png
# Scatter plot saved for Gage ID: 1534000 at Sanford_Scatter_Plots\Gage_1534000_scatter.png
# Scatter plot saved for Gage ID: 1536000 at Sanford_Scatter_Plots\Gage_1536000_scatter.png
# Scatter plot saved for Gage ID: 1538000 at Sanford_Scatter_Plots\Gage_1538000_scatter.png
# Scatter plot saved for Gage ID: 1539000 at Sanford_Scatter_Plots\Gage_1539000_scatter.png
# Scatter plot saved for Gage ID: 1541000 at Sanford_Scatter_Plots\Gage_1541000_scatter.png
# Scatter plot saved for Gage ID: 1541200 at Sanford_Scatter_Plots\Gage_1541200_scatter.png
# Scatter plot saved for Gage ID: 1541500 at Sanford_Scatter_Plots\Gage_1541500_scatter.png
# Scatter plot saved for Gage ID: 1542810 at Sanford_Scatter_Plots\Gage_1542810_scatter.png
# Scatter plot saved for Gage ID: 1543000 at Sanford_Scatter_Plots\Gage_1543000_scatter.png
# Scatter plot saved for Gage ID: 1543500 at Sanford_Scatter_Plots\Gage_1543500_scatter.png
# Scatter plot saved for Gage ID: 1544000 at Sanford_Scatter_Plots\Gage_1544000_scatter.png
# Scatter plot saved for Gage ID: 1544500 at Sanford_Scatter_Plots\Gage_1544500_scatter.png
# Scatter plot saved for Gage ID: 1545000 at Sanford_Scatter_Plots\Gage_1545000_scatter.png
# Scatter plot saved for Gage ID: 1545600 at Sanford_Scatter_Plots\Gage_1545600_scatter.png
# Scatter plot saved for Gage ID: 1546500 at Sanford_Scatter_Plots\Gage_1546500_scatter.png
# Scatter plot saved for Gage ID: 1547500 at Sanford_Scatter_Plots\Gage_1547500_scatter.png
# Scatter plot saved for Gage ID: 1547700 at Sanford_Scatter_Plots\Gage_1547700_scatter.png
# Scatter plot saved for Gage ID: 1547950 at Sanford_Scatter_Plots\Gage_1547950_scatter.png
# Scatter plot saved for Gage ID: 1548500 at Sanford_Scatter_Plots\Gage_1548500_scatter.png
# Scatter plot saved for Gage ID: 1549500 at Sanford_Scatter_Plots\Gage_1549500_scatter.png
# Scatter plot saved for Gage ID: 1550000 at Sanford_Scatter_Plots\Gage_1550000_scatter.png
# Scatter plot saved for Gage ID: 1552000 at Sanford_Scatter_Plots\Gage_1552000_scatter.png
# Scatter plot saved for Gage ID: 1552500 at Sanford_Scatter_Plots\Gage_1552500_scatter.png
# Scatter plot saved for Gage ID: 1555000 at Sanford_Scatter_Plots\Gage_1555000_scatter.png
# Scatter plot saved for Gage ID: 1555500 at Sanford_Scatter_Plots\Gage_1555500_scatter.png
# Scatter plot saved for Gage ID: 1556000 at Sanford_Scatter_Plots\Gage_1556000_scatter.png
# Scatter plot saved for Gage ID: 1557500 at Sanford_Scatter_Plots\Gage_1557500_scatter.png
# Scatter plot saved for Gage ID: 1558000 at Sanford_Scatter_Plots\Gage_1558000_scatter.png
# Scatter plot saved for Gage ID: 1560000 at Sanford_Scatter_Plots\Gage_1560000_scatter.png
# Scatter plot saved for Gage ID: 1564500 at Sanford_Scatter_Plots\Gage_1564500_scatter.png
# Scatter plot saved for Gage ID: 1567500 at Sanford_Scatter_Plots\Gage_1567500_scatter.png
# Scatter plot saved for Gage ID: 1568000 at Sanford_Scatter_Plots\Gage_1568000_scatter.png
# Scatter plot saved for Gage ID: 1571500 at Sanford_Scatter_Plots\Gage_1571500_scatter.png
# Scatter plot saved for Gage ID: 1573000 at Sanford_Scatter_Plots\Gage_1573000_scatter.png
# Scatter plot saved for Gage ID: 1576500 at Sanford_Scatter_Plots\Gage_1576500_scatter.png
# Scatter plot saved for Gage ID: 1580000 at Sanford_Scatter_Plots\Gage_1580000_scatter.png
# Scatter plot saved for Gage ID: 1582000 at Sanford_Scatter_Plots\Gage_1582000_scatter.png
# Scatter plot saved for Gage ID: 1583500 at Sanford_Scatter_Plots\Gage_1583500_scatter.png
# Scatter plot saved for Gage ID: 1586000 at Sanford_Scatter_Plots\Gage_1586000_scatter.png
# Scatter plot saved for Gage ID: 1586610 at Sanford_Scatter_Plots\Gage_1586610_scatter.png
# Scatter plot saved for Gage ID: 1591400 at Sanford_Scatter_Plots\Gage_1591400_scatter.png
# Scatter plot saved for Gage ID: 1595200 at Sanford_Scatter_Plots\Gage_1595200_scatter.png
# Scatter plot saved for Gage ID: 1596500 at Sanford_Scatter_Plots\Gage_1596500_scatter.png
# Scatter plot saved for Gage ID: 1599000 at Sanford_Scatter_Plots\Gage_1599000_scatter.png
# Scatter plot saved for Gage ID: 1601500 at Sanford_Scatter_Plots\Gage_1601500_scatter.png
# Scatter plot saved for Gage ID: 1604500 at Sanford_Scatter_Plots\Gage_1604500_scatter.png
# Scatter plot saved for Gage ID: 1605500 at Sanford_Scatter_Plots\Gage_1605500_scatter.png
# Scatter plot saved for Gage ID: 1606500 at Sanford_Scatter_Plots\Gage_1606500_scatter.png
# Scatter plot saved for Gage ID: 1607500 at Sanford_Scatter_Plots\Gage_1607500_scatter.png
# Scatter plot saved for Gage ID: 1613050 at Sanford_Scatter_Plots\Gage_1613050_scatter.png
# Scatter plot saved for Gage ID: 1616500 at Sanford_Scatter_Plots\Gage_1616500_scatter.png
# Scatter plot saved for Gage ID: 1619500 at Sanford_Scatter_Plots\Gage_1619500_scatter.png
# Scatter plot saved for Gage ID: 1620500 at Sanford_Scatter_Plots\Gage_1620500_scatter.png
# Scatter plot saved for Gage ID: 1625000 at Sanford_Scatter_Plots\Gage_1625000_scatter.png
# Scatter plot saved for Gage ID: 1626000 at Sanford_Scatter_Plots\Gage_1626000_scatter.png
# Scatter plot saved for Gage ID: 1632000 at Sanford_Scatter_Plots\Gage_1632000_scatter.png
# Scatter plot saved for Gage ID: 1632900 at Sanford_Scatter_Plots\Gage_1632900_scatter.png
# Scatter plot saved for Gage ID: 1634500 at Sanford_Scatter_Plots\Gage_1634500_scatter.png
# Scatter plot saved for Gage ID: 1635500 at Sanford_Scatter_Plots\Gage_1635500_scatter.png
# Scatter plot saved for Gage ID: 1637500 at Sanford_Scatter_Plots\Gage_1637500_scatter.png
# Scatter plot saved for Gage ID: 1638480 at Sanford_Scatter_Plots\Gage_1638480_scatter.png
# Scatter plot saved for Gage ID: 1639000 at Sanford_Scatter_Plots\Gage_1639000_scatter.png
# Scatter plot saved for Gage ID: 1639500 at Sanford_Scatter_Plots\Gage_1639500_scatter.png
# Scatter plot saved for Gage ID: 1643500 at Sanford_Scatter_Plots\Gage_1643500_scatter.png
# Scatter plot saved for Gage ID: 1644000 at Sanford_Scatter_Plots\Gage_1644000_scatter.png
# Scatter plot saved for Gage ID: 1645000 at Sanford_Scatter_Plots\Gage_1645000_scatter.png
# Scatter plot saved for Gage ID: 1646000 at Sanford_Scatter_Plots\Gage_1646000_scatter.png
# Scatter plot saved for Gage ID: 1648000 at Sanford_Scatter_Plots\Gage_1648000_scatter.png
# Scatter plot saved for Gage ID: 1649500 at Sanford_Scatter_Plots\Gage_1649500_scatter.png
# Scatter plot saved for Gage ID: 1651000 at Sanford_Scatter_Plots\Gage_1651000_scatter.png
# Scatter plot saved for Gage ID: 1653600 at Sanford_Scatter_Plots\Gage_1653600_scatter.png
# Scatter plot saved for Gage ID: 1658500 at Sanford_Scatter_Plots\Gage_1658500_scatter.png
# Scatter plot saved for Gage ID: 1664000 at Sanford_Scatter_Plots\Gage_1664000_scatter.png
# Scatter plot saved for Gage ID: 1666500 at Sanford_Scatter_Plots\Gage_1666500_scatter.png
# Scatter plot saved for Gage ID: 1667500 at Sanford_Scatter_Plots\Gage_1667500_scatter.png
# Scatter plot saved for Gage ID: 1669000 at Sanford_Scatter_Plots\Gage_1669000_scatter.png
# Scatter plot saved for Gage ID: 1669520 at Sanford_Scatter_Plots\Gage_1669520_scatter.png
# Scatter plot saved for Gage ID: 1673800 at Sanford_Scatter_Plots\Gage_1673800_scatter.png
# Scatter plot saved for Gage ID: 1674000 at Sanford_Scatter_Plots\Gage_1674000_scatter.png
# Scatter plot saved for Gage ID: 2011400 at Sanford_Scatter_Plots\Gage_2011400_scatter.png
# Scatter plot saved for Gage ID: 2011460 at Sanford_Scatter_Plots\Gage_2011460_scatter.png
# Scatter plot saved for Gage ID: 2013000 at Sanford_Scatter_Plots\Gage_2013000_scatter.png
# Scatter plot saved for Gage ID: 2014000 at Sanford_Scatter_Plots\Gage_2014000_scatter.png
# Scatter plot saved for Gage ID: 2015700 at Sanford_Scatter_Plots\Gage_2015700_scatter.png
# Scatter plot saved for Gage ID: 2016000 at Sanford_Scatter_Plots\Gage_2016000_scatter.png
# Scatter plot saved for Gage ID: 2017500 at Sanford_Scatter_Plots\Gage_2017500_scatter.png
# Scatter plot saved for Gage ID: 2018000 at Sanford_Scatter_Plots\Gage_2018000_scatter.png
# Scatter plot saved for Gage ID: 2021500 at Sanford_Scatter_Plots\Gage_2021500_scatter.png
# Scatter plot saved for Gage ID: 2027000 at Sanford_Scatter_Plots\Gage_2027000_scatter.png
# Scatter plot saved for Gage ID: 2027500 at Sanford_Scatter_Plots\Gage_2027500_scatter.png
# Scatter plot saved for Gage ID: 2028500 at Sanford_Scatter_Plots\Gage_2028500_scatter.png
# Scatter plot saved for Gage ID: 2038850 at Sanford_Scatter_Plots\Gage_2038850_scatter.png
# Scatter plot saved for Gage ID: 2039000 at Sanford_Scatter_Plots\Gage_2039000_scatter.png
# Scatter plot saved for Gage ID: 2039500 at Sanford_Scatter_Plots\Gage_2039500_scatter.png
# Scatter plot saved for Gage ID: 2041000 at Sanford_Scatter_Plots\Gage_2041000_scatter.png
# Scatter plot saved for Gage ID: 2042500 at Sanford_Scatter_Plots\Gage_2042500_scatter.png
# Scatter plot saved for Gage ID: 2044500 at Sanford_Scatter_Plots\Gage_2044500_scatter.png
# Scatter plot saved for Gage ID: 2046000 at Sanford_Scatter_Plots\Gage_2046000_scatter.png
# Scatter plot saved for Gage ID: 2051000 at Sanford_Scatter_Plots\Gage_2051000_scatter.png
# Scatter plot saved for Gage ID: 2051500 at Sanford_Scatter_Plots\Gage_2051500_scatter.png
# Scatter plot saved for Gage ID: 2053200 at Sanford_Scatter_Plots\Gage_2053200_scatter.png
# Scatter plot saved for Gage ID: 2053500 at Sanford_Scatter_Plots\Gage_2053500_scatter.png
# Scatter plot saved for Gage ID: 2053800 at Sanford_Scatter_Plots\Gage_2053800_scatter.png
# Scatter plot saved for Gage ID: 2054500 at Sanford_Scatter_Plots\Gage_2054500_scatter.png
# Scatter plot saved for Gage ID: 2055100 at Sanford_Scatter_Plots\Gage_2055100_scatter.png
# Scatter plot saved for Gage ID: 2056900 at Sanford_Scatter_Plots\Gage_2056900_scatter.png
# Scatter plot saved for Gage ID: 2058400 at Sanford_Scatter_Plots\Gage_2058400_scatter.png
# Scatter plot saved for Gage ID: 2059500 at Sanford_Scatter_Plots\Gage_2059500_scatter.png
# Scatter plot saved for Gage ID: 2064000 at Sanford_Scatter_Plots\Gage_2064000_scatter.png
# Scatter plot saved for Gage ID: 2065500 at Sanford_Scatter_Plots\Gage_2065500_scatter.png
# Scatter plot saved for Gage ID: 2069700 at Sanford_Scatter_Plots\Gage_2069700_scatter.png
# Scatter plot saved for Gage ID: 2070000 at Sanford_Scatter_Plots\Gage_2070000_scatter.png
# Scatter plot saved for Gage ID: 2073000 at Sanford_Scatter_Plots\Gage_2073000_scatter.png
# Scatter plot saved for Gage ID: 2074500 at Sanford_Scatter_Plots\Gage_2074500_scatter.png
# Scatter plot saved for Gage ID: 2077200 at Sanford_Scatter_Plots\Gage_2077200_scatter.png
# Scatter plot saved for Gage ID: 2081500 at Sanford_Scatter_Plots\Gage_2081500_scatter.png
# Scatter plot saved for Gage ID: 2082950 at Sanford_Scatter_Plots\Gage_2082950_scatter.png
# Scatter plot saved for Gage ID: 2085500 at Sanford_Scatter_Plots\Gage_2085500_scatter.png
# Scatter plot saved for Gage ID: 2088000 at Sanford_Scatter_Plots\Gage_2088000_scatter.png
# Scatter plot saved for Gage ID: 2090380 at Sanford_Scatter_Plots\Gage_2090380_scatter.png
# Scatter plot saved for Gage ID: 2091000 at Sanford_Scatter_Plots\Gage_2091000_scatter.png
# Scatter plot saved for Gage ID: 2092500 at Sanford_Scatter_Plots\Gage_2092500_scatter.png
# Scatter plot saved for Gage ID: 2094500 at Sanford_Scatter_Plots\Gage_2094500_scatter.png
# Scatter plot saved for Gage ID: 2096846 at Sanford_Scatter_Plots\Gage_2096846_scatter.png
# Scatter plot saved for Gage ID: 2100500 at Sanford_Scatter_Plots\Gage_2100500_scatter.png
# Scatter plot saved for Gage ID: 2102908 at Sanford_Scatter_Plots\Gage_2102908_scatter.png
# Scatter plot saved for Gage ID: 2108000 at Sanford_Scatter_Plots\Gage_2108000_scatter.png
# Scatter plot saved for Gage ID: 2111180 at Sanford_Scatter_Plots\Gage_2111180_scatter.png
# Scatter plot saved for Gage ID: 2111500 at Sanford_Scatter_Plots\Gage_2111500_scatter.png
# Scatter plot saved for Gage ID: 2112120 at Sanford_Scatter_Plots\Gage_2112120_scatter.png
# Scatter plot saved for Gage ID: 2112360 at Sanford_Scatter_Plots\Gage_2112360_scatter.png
# Scatter plot saved for Gage ID: 2113000 at Sanford_Scatter_Plots\Gage_2113000_scatter.png
# Scatter plot saved for Gage ID: 2113850 at Sanford_Scatter_Plots\Gage_2113850_scatter.png
# Scatter plot saved for Gage ID: 2114450 at Sanford_Scatter_Plots\Gage_2114450_scatter.png
# Scatter plot saved for Gage ID: 2118000 at Sanford_Scatter_Plots\Gage_2118000_scatter.png
# Scatter plot saved for Gage ID: 2118500 at Sanford_Scatter_Plots\Gage_2118500_scatter.png
# Scatter plot saved for Gage ID: 2125000 at Sanford_Scatter_Plots\Gage_2125000_scatter.png
# Scatter plot saved for Gage ID: 2128000 at Sanford_Scatter_Plots\Gage_2128000_scatter.png
# Scatter plot saved for Gage ID: 2133500 at Sanford_Scatter_Plots\Gage_2133500_scatter.png
# Scatter plot saved for Gage ID: 2137727 at Sanford_Scatter_Plots\Gage_2137727_scatter.png
# Scatter plot saved for Gage ID: 2138500 at Sanford_Scatter_Plots\Gage_2138500_scatter.png
# Scatter plot saved for Gage ID: 2140991 at Sanford_Scatter_Plots\Gage_2140991_scatter.png
# Scatter plot saved for Gage ID: 2143000 at Sanford_Scatter_Plots\Gage_2143000_scatter.png
# Scatter plot saved for Gage ID: 2143040 at Sanford_Scatter_Plots\Gage_2143040_scatter.png
# Scatter plot saved for Gage ID: 2143500 at Sanford_Scatter_Plots\Gage_2143500_scatter.png
# Scatter plot saved for Gage ID: 2146600 at Sanford_Scatter_Plots\Gage_2146600_scatter.png
# Scatter plot saved for Gage ID: 2149000 at Sanford_Scatter_Plots\Gage_2149000_scatter.png
# Scatter plot saved for Gage ID: 2152100 at Sanford_Scatter_Plots\Gage_2152100_scatter.png
# Scatter plot saved for Gage ID: 2169570 at Sanford_Scatter_Plots\Gage_2169570_scatter.png
# Scatter plot saved for Gage ID: 2177000 at Sanford_Scatter_Plots\Gage_2177000_scatter.png
# Scatter plot saved for Gage ID: 2178400 at Sanford_Scatter_Plots\Gage_2178400_scatter.png
# Scatter plot saved for Gage ID: 2193340 at Sanford_Scatter_Plots\Gage_2193340_scatter.png
# Scatter plot saved for Gage ID: 2198100 at Sanford_Scatter_Plots\Gage_2198100_scatter.png
# Scatter plot saved for Gage ID: 2202600 at Sanford_Scatter_Plots\Gage_2202600_scatter.png
# Scatter plot saved for Gage ID: 2212600 at Sanford_Scatter_Plots\Gage_2212600_scatter.png
# Scatter plot saved for Gage ID: 2213500 at Sanford_Scatter_Plots\Gage_2213500_scatter.png
# Scatter plot saved for Gage ID: 2215100 at Sanford_Scatter_Plots\Gage_2215100_scatter.png
# Scatter plot saved for Gage ID: 2216180 at Sanford_Scatter_Plots\Gage_2216180_scatter.png
# Scatter plot saved for Gage ID: 2221525 at Sanford_Scatter_Plots\Gage_2221525_scatter.png
# Scatter plot saved for Gage ID: 2231000 at Sanford_Scatter_Plots\Gage_2231000_scatter.png
# Scatter plot saved for Gage ID: 2231342 at Sanford_Scatter_Plots\Gage_2231342_scatter.png
# Scatter plot saved for Gage ID: 2235200 at Sanford_Scatter_Plots\Gage_2235200_scatter.png
# Scatter plot saved for Gage ID: 2245500 at Sanford_Scatter_Plots\Gage_2245500_scatter.png
# Scatter plot saved for Gage ID: 2246000 at Sanford_Scatter_Plots\Gage_2246000_scatter.png
# Scatter plot saved for Gage ID: 2296500 at Sanford_Scatter_Plots\Gage_2296500_scatter.png
# Scatter plot saved for Gage ID: 2297155 at Sanford_Scatter_Plots\Gage_2297155_scatter.png
# Scatter plot saved for Gage ID: 2297310 at Sanford_Scatter_Plots\Gage_2297310_scatter.png
# Scatter plot saved for Gage ID: 2298123 at Sanford_Scatter_Plots\Gage_2298123_scatter.png
# Scatter plot saved for Gage ID: 2298608 at Sanford_Scatter_Plots\Gage_2298608_scatter.png
# Scatter plot saved for Gage ID: 2299950 at Sanford_Scatter_Plots\Gage_2299950_scatter.png
# Scatter plot saved for Gage ID: 2300700 at Sanford_Scatter_Plots\Gage_2300700_scatter.png
# Scatter plot saved for Gage ID: 2310947 at Sanford_Scatter_Plots\Gage_2310947_scatter.png
# Scatter plot saved for Gage ID: 2312200 at Sanford_Scatter_Plots\Gage_2312200_scatter.png
# Scatter plot saved for Gage ID: 2314500 at Sanford_Scatter_Plots\Gage_2314500_scatter.png
# Scatter plot saved for Gage ID: 2315500 at Sanford_Scatter_Plots\Gage_2315500_scatter.png
# Scatter plot saved for Gage ID: 2324400 at Sanford_Scatter_Plots\Gage_2324400_scatter.png
# Scatter plot saved for Gage ID: 2327100 at Sanford_Scatter_Plots\Gage_2327100_scatter.png
# Scatter plot saved for Gage ID: 2331600 at Sanford_Scatter_Plots\Gage_2331600_scatter.png
# Scatter plot saved for Gage ID: 2333500 at Sanford_Scatter_Plots\Gage_2333500_scatter.png
# Scatter plot saved for Gage ID: 2335700 at Sanford_Scatter_Plots\Gage_2335700_scatter.png
# Scatter plot saved for Gage ID: 2336300 at Sanford_Scatter_Plots\Gage_2336300_scatter.png
# Scatter plot saved for Gage ID: 2337000 at Sanford_Scatter_Plots\Gage_2337000_scatter.png
# Scatter plot saved for Gage ID: 2341800 at Sanford_Scatter_Plots\Gage_2341800_scatter.png
# Scatter plot saved for Gage ID: 2342500 at Sanford_Scatter_Plots\Gage_2342500_scatter.png
# Scatter plot saved for Gage ID: 2342933 at Sanford_Scatter_Plots\Gage_2342933_scatter.png
# Scatter plot saved for Gage ID: 2344500 at Sanford_Scatter_Plots\Gage_2344500_scatter.png
# Scatter plot saved for Gage ID: 2344700 at Sanford_Scatter_Plots\Gage_2344700_scatter.png
# Scatter plot saved for Gage ID: 2349900 at Sanford_Scatter_Plots\Gage_2349900_scatter.png
# Scatter plot saved for Gage ID: 2350900 at Sanford_Scatter_Plots\Gage_2350900_scatter.png
# Scatter plot saved for Gage ID: 2361000 at Sanford_Scatter_Plots\Gage_2361000_scatter.png
# Scatter plot saved for Gage ID: 2363000 at Sanford_Scatter_Plots\Gage_2363000_scatter.png
# Scatter plot saved for Gage ID: 2369800 at Sanford_Scatter_Plots\Gage_2369800_scatter.png
# Scatter plot saved for Gage ID: 2371500 at Sanford_Scatter_Plots\Gage_2371500_scatter.png
# Scatter plot saved for Gage ID: 2372250 at Sanford_Scatter_Plots\Gage_2372250_scatter.png
# Scatter plot saved for Gage ID: 2374500 at Sanford_Scatter_Plots\Gage_2374500_scatter.png
# Scatter plot saved for Gage ID: 2380500 at Sanford_Scatter_Plots\Gage_2380500_scatter.png
# Scatter plot saved for Gage ID: 2381600 at Sanford_Scatter_Plots\Gage_2381600_scatter.png
# Scatter plot saved for Gage ID: 2385800 at Sanford_Scatter_Plots\Gage_2385800_scatter.png
# Scatter plot saved for Gage ID: 2395120 at Sanford_Scatter_Plots\Gage_2395120_scatter.png
# Scatter plot saved for Gage ID: 2398000 at Sanford_Scatter_Plots\Gage_2398000_scatter.png
# Scatter plot saved for Gage ID: 2399200 at Sanford_Scatter_Plots\Gage_2399200_scatter.png
# Scatter plot saved for Gage ID: 2401390 at Sanford_Scatter_Plots\Gage_2401390_scatter.png
# Scatter plot saved for Gage ID: 2408540 at Sanford_Scatter_Plots\Gage_2408540_scatter.png
# Scatter plot saved for Gage ID: 2415000 at Sanford_Scatter_Plots\Gage_2415000_scatter.png
# Scatter plot saved for Gage ID: 2422500 at Sanford_Scatter_Plots\Gage_2422500_scatter.png
# Scatter plot saved for Gage ID: 2427250 at Sanford_Scatter_Plots\Gage_2427250_scatter.png
# Scatter plot saved for Gage ID: 2430085 at Sanford_Scatter_Plots\Gage_2430085_scatter.png
# Scatter plot saved for Gage ID: 2430615 at Sanford_Scatter_Plots\Gage_2430615_scatter.png
# Scatter plot saved for Gage ID: 2450000 at Sanford_Scatter_Plots\Gage_2450000_scatter.png
# Scatter plot saved for Gage ID: 2450250 at Sanford_Scatter_Plots\Gage_2450250_scatter.png
# Scatter plot saved for Gage ID: 2464000 at Sanford_Scatter_Plots\Gage_2464000_scatter.png
# Scatter plot saved for Gage ID: 2464146 at Sanford_Scatter_Plots\Gage_2464146_scatter.png
# Scatter plot saved for Gage ID: 2464360 at Sanford_Scatter_Plots\Gage_2464360_scatter.png
# Scatter plot saved for Gage ID: 2465493 at Sanford_Scatter_Plots\Gage_2465493_scatter.png
# Scatter plot saved for Gage ID: 2469800 at Sanford_Scatter_Plots\Gage_2469800_scatter.png
# Scatter plot saved for Gage ID: 2471001 at Sanford_Scatter_Plots\Gage_2471001_scatter.png
# Scatter plot saved for Gage ID: 2472000 at Sanford_Scatter_Plots\Gage_2472000_scatter.png
# Scatter plot saved for Gage ID: 2472500 at Sanford_Scatter_Plots\Gage_2472500_scatter.png
# Scatter plot saved for Gage ID: 2473500 at Sanford_Scatter_Plots\Gage_2473500_scatter.png
# Scatter plot saved for Gage ID: 2475500 at Sanford_Scatter_Plots\Gage_2475500_scatter.png
# Scatter plot saved for Gage ID: 2476500 at Sanford_Scatter_Plots\Gage_2476500_scatter.png
# Scatter plot saved for Gage ID: 2476600 at Sanford_Scatter_Plots\Gage_2476600_scatter.png
# Scatter plot saved for Gage ID: 2479130 at Sanford_Scatter_Plots\Gage_2479130_scatter.png
# Scatter plot saved for Gage ID: 2479155 at Sanford_Scatter_Plots\Gage_2479155_scatter.png
# Scatter plot saved for Gage ID: 2479300 at Sanford_Scatter_Plots\Gage_2479300_scatter.png
# Scatter plot saved for Gage ID: 2479560 at Sanford_Scatter_Plots\Gage_2479560_scatter.png
# Scatter plot saved for Gage ID: 2481000 at Sanford_Scatter_Plots\Gage_2481000_scatter.png
# Scatter plot saved for Gage ID: 2481510 at Sanford_Scatter_Plots\Gage_2481510_scatter.png
# Scatter plot saved for Gage ID: 2484000 at Sanford_Scatter_Plots\Gage_2484000_scatter.png
# Scatter plot saved for Gage ID: 3010655 at Sanford_Scatter_Plots\Gage_3010655_scatter.png
# Scatter plot saved for Gage ID: 3011800 at Sanford_Scatter_Plots\Gage_3011800_scatter.png
# Scatter plot saved for Gage ID: 3014500 at Sanford_Scatter_Plots\Gage_3014500_scatter.png
# Scatter plot saved for Gage ID: 3015500 at Sanford_Scatter_Plots\Gage_3015500_scatter.png
# Scatter plot saved for Gage ID: 3020500 at Sanford_Scatter_Plots\Gage_3020500_scatter.png
# Scatter plot saved for Gage ID: 3021350 at Sanford_Scatter_Plots\Gage_3021350_scatter.png
# Scatter plot saved for Gage ID: 3026500 at Sanford_Scatter_Plots\Gage_3026500_scatter.png
# Scatter plot saved for Gage ID: 3028000 at Sanford_Scatter_Plots\Gage_3028000_scatter.png
# Scatter plot saved for Gage ID: 3034000 at Sanford_Scatter_Plots\Gage_3034000_scatter.png
# Scatter plot saved for Gage ID: 3034500 at Sanford_Scatter_Plots\Gage_3034500_scatter.png
# Scatter plot saved for Gage ID: 3038000 at Sanford_Scatter_Plots\Gage_3038000_scatter.png
# Scatter plot saved for Gage ID: 3042000 at Sanford_Scatter_Plots\Gage_3042000_scatter.png
# Scatter plot saved for Gage ID: 3042280 at Sanford_Scatter_Plots\Gage_3042280_scatter.png
# Scatter plot saved for Gage ID: 3042500 at Sanford_Scatter_Plots\Gage_3042500_scatter.png
# Scatter plot saved for Gage ID: 3045000 at Sanford_Scatter_Plots\Gage_3045000_scatter.png
# Scatter plot saved for Gage ID: 3049000 at Sanford_Scatter_Plots\Gage_3049000_scatter.png
# Scatter plot saved for Gage ID: 3049800 at Sanford_Scatter_Plots\Gage_3049800_scatter.png
# Scatter plot saved for Gage ID: 3050000 at Sanford_Scatter_Plots\Gage_3050000_scatter.png
# Scatter plot saved for Gage ID: 3053500 at Sanford_Scatter_Plots\Gage_3053500_scatter.png
# Scatter plot saved for Gage ID: 3061500 at Sanford_Scatter_Plots\Gage_3061500_scatter.png
# Scatter plot saved for Gage ID: 3066000 at Sanford_Scatter_Plots\Gage_3066000_scatter.png
# Scatter plot saved for Gage ID: 3069500 at Sanford_Scatter_Plots\Gage_3069500_scatter.png
# Scatter plot saved for Gage ID: 3070500 at Sanford_Scatter_Plots\Gage_3070500_scatter.png
# Scatter plot saved for Gage ID: 3072000 at Sanford_Scatter_Plots\Gage_3072000_scatter.png
# Scatter plot saved for Gage ID: 3074500 at Sanford_Scatter_Plots\Gage_3074500_scatter.png
# Scatter plot saved for Gage ID: 3076500 at Sanford_Scatter_Plots\Gage_3076500_scatter.png
# Scatter plot saved for Gage ID: 3076600 at Sanford_Scatter_Plots\Gage_3076600_scatter.png
# Scatter plot saved for Gage ID: 3078000 at Sanford_Scatter_Plots\Gage_3078000_scatter.png
# Scatter plot saved for Gage ID: 3079000 at Sanford_Scatter_Plots\Gage_3079000_scatter.png
# Scatter plot saved for Gage ID: 3080000 at Sanford_Scatter_Plots\Gage_3080000_scatter.png
# Scatter plot saved for Gage ID: 3085500 at Sanford_Scatter_Plots\Gage_3085500_scatter.png
# Scatter plot saved for Gage ID: 3091500 at Sanford_Scatter_Plots\Gage_3091500_scatter.png
# Scatter plot saved for Gage ID: 3093000 at Sanford_Scatter_Plots\Gage_3093000_scatter.png
# Scatter plot saved for Gage ID: 3102850 at Sanford_Scatter_Plots\Gage_3102850_scatter.png
# Scatter plot saved for Gage ID: 3106000 at Sanford_Scatter_Plots\Gage_3106000_scatter.png
# Scatter plot saved for Gage ID: 3108000 at Sanford_Scatter_Plots\Gage_3108000_scatter.png
# Scatter plot saved for Gage ID: 3110000 at Sanford_Scatter_Plots\Gage_3110000_scatter.png
# Scatter plot saved for Gage ID: 3111500 at Sanford_Scatter_Plots\Gage_3111500_scatter.png
# Scatter plot saved for Gage ID: 3112000 at Sanford_Scatter_Plots\Gage_3112000_scatter.png
# Scatter plot saved for Gage ID: 3117500 at Sanford_Scatter_Plots\Gage_3117500_scatter.png
# Scatter plot saved for Gage ID: 3118000 at Sanford_Scatter_Plots\Gage_3118000_scatter.png
# Scatter plot saved for Gage ID: 3118500 at Sanford_Scatter_Plots\Gage_3118500_scatter.png
# Scatter plot saved for Gage ID: 3136500 at Sanford_Scatter_Plots\Gage_3136500_scatter.png
# Scatter plot saved for Gage ID: 3140000 at Sanford_Scatter_Plots\Gage_3140000_scatter.png
# Scatter plot saved for Gage ID: 3145000 at Sanford_Scatter_Plots\Gage_3145000_scatter.png
# Scatter plot saved for Gage ID: 3157000 at Sanford_Scatter_Plots\Gage_3157000_scatter.png
# Scatter plot saved for Gage ID: 3159540 at Sanford_Scatter_Plots\Gage_3159540_scatter.png
# Scatter plot saved for Gage ID: 3161000 at Sanford_Scatter_Plots\Gage_3161000_scatter.png
# Scatter plot saved for Gage ID: 3164000 at Sanford_Scatter_Plots\Gage_3164000_scatter.png
# Scatter plot saved for Gage ID: 3165000 at Sanford_Scatter_Plots\Gage_3165000_scatter.png
# Scatter plot saved for Gage ID: 3167000 at Sanford_Scatter_Plots\Gage_3167000_scatter.png
# Scatter plot saved for Gage ID: 3170000 at Sanford_Scatter_Plots\Gage_3170000_scatter.png
# Scatter plot saved for Gage ID: 3173000 at Sanford_Scatter_Plots\Gage_3173000_scatter.png
# Scatter plot saved for Gage ID: 3180500 at Sanford_Scatter_Plots\Gage_3180500_scatter.png
# Scatter plot saved for Gage ID: 3182500 at Sanford_Scatter_Plots\Gage_3182500_scatter.png
# Scatter plot saved for Gage ID: 3186500 at Sanford_Scatter_Plots\Gage_3186500_scatter.png
# Scatter plot saved for Gage ID: 3187500 at Sanford_Scatter_Plots\Gage_3187500_scatter.png
# Scatter plot saved for Gage ID: 3202400 at Sanford_Scatter_Plots\Gage_3202400_scatter.png
# Scatter plot saved for Gage ID: 3207800 at Sanford_Scatter_Plots\Gage_3207800_scatter.png
# Scatter plot saved for Gage ID: 3208500 at Sanford_Scatter_Plots\Gage_3208500_scatter.png
# Scatter plot saved for Gage ID: 3208950 at Sanford_Scatter_Plots\Gage_3208950_scatter.png
# Scatter plot saved for Gage ID: 3209000 at Sanford_Scatter_Plots\Gage_3209000_scatter.png
# Scatter plot saved for Gage ID: 3213700 at Sanford_Scatter_Plots\Gage_3213700_scatter.png
# Scatter plot saved for Gage ID: 3217000 at Sanford_Scatter_Plots\Gage_3217000_scatter.png
# Scatter plot saved for Gage ID: 3220000 at Sanford_Scatter_Plots\Gage_3220000_scatter.png
# Scatter plot saved for Gage ID: 3228500 at Sanford_Scatter_Plots\Gage_3228500_scatter.png
# Scatter plot saved for Gage ID: 3232500 at Sanford_Scatter_Plots\Gage_3232500_scatter.png
# Scatter plot saved for Gage ID: 3237280 at Sanford_Scatter_Plots\Gage_3237280_scatter.png
# Scatter plot saved for Gage ID: 3237500 at Sanford_Scatter_Plots\Gage_3237500_scatter.png
# Scatter plot saved for Gage ID: 3238500 at Sanford_Scatter_Plots\Gage_3238500_scatter.png
# Scatter plot saved for Gage ID: 3240000 at Sanford_Scatter_Plots\Gage_3240000_scatter.png
# Scatter plot saved for Gage ID: 3241500 at Sanford_Scatter_Plots\Gage_3241500_scatter.png
# Scatter plot saved for Gage ID: 3262000 at Sanford_Scatter_Plots\Gage_3262000_scatter.png
# Scatter plot saved for Gage ID: 3264000 at Sanford_Scatter_Plots\Gage_3264000_scatter.png
# Scatter plot saved for Gage ID: 3272000 at Sanford_Scatter_Plots\Gage_3272000_scatter.png
# Scatter plot saved for Gage ID: 3275600 at Sanford_Scatter_Plots\Gage_3275600_scatter.png
# Scatter plot saved for Gage ID: 3280700 at Sanford_Scatter_Plots\Gage_3280700_scatter.png
# Scatter plot saved for Gage ID: 3281100 at Sanford_Scatter_Plots\Gage_3281100_scatter.png
# Scatter plot saved for Gage ID: 3281500 at Sanford_Scatter_Plots\Gage_3281500_scatter.png
# Scatter plot saved for Gage ID: 3283500 at Sanford_Scatter_Plots\Gage_3283500_scatter.png
# Scatter plot saved for Gage ID: 3285000 at Sanford_Scatter_Plots\Gage_3285000_scatter.png
# Scatter plot saved for Gage ID: 3291780 at Sanford_Scatter_Plots\Gage_3291780_scatter.png
# Scatter plot saved for Gage ID: 3294000 at Sanford_Scatter_Plots\Gage_3294000_scatter.png
# Scatter plot saved for Gage ID: 3300400 at Sanford_Scatter_Plots\Gage_3300400_scatter.png
# Scatter plot saved for Gage ID: 3302800 at Sanford_Scatter_Plots\Gage_3302800_scatter.png
# Scatter plot saved for Gage ID: 3303300 at Sanford_Scatter_Plots\Gage_3303300_scatter.png
# Scatter plot saved for Gage ID: 3310300 at Sanford_Scatter_Plots\Gage_3310300_scatter.png
# Scatter plot saved for Gage ID: 3320500 at Sanford_Scatter_Plots\Gage_3320500_scatter.png
# Scatter plot saved for Gage ID: 3324000 at Sanford_Scatter_Plots\Gage_3324000_scatter.png
# Scatter plot saved for Gage ID: 3325500 at Sanford_Scatter_Plots\Gage_3325500_scatter.png
# Scatter plot saved for Gage ID: 3329700 at Sanford_Scatter_Plots\Gage_3329700_scatter.png
# Scatter plot saved for Gage ID: 3330500 at Sanford_Scatter_Plots\Gage_3330500_scatter.png
# Scatter plot saved for Gage ID: 3333450 at Sanford_Scatter_Plots\Gage_3333450_scatter.png
# Scatter plot saved for Gage ID: 3334500 at Sanford_Scatter_Plots\Gage_3334500_scatter.png
# Scatter plot saved for Gage ID: 3338780 at Sanford_Scatter_Plots\Gage_3338780_scatter.png
# Scatter plot saved for Gage ID: 3340800 at Sanford_Scatter_Plots\Gage_3340800_scatter.png
# Scatter plot saved for Gage ID: 3342500 at Sanford_Scatter_Plots\Gage_3342500_scatter.png
# Scatter plot saved for Gage ID: 3343400 at Sanford_Scatter_Plots\Gage_3343400_scatter.png
# Scatter plot saved for Gage ID: 3346000 at Sanford_Scatter_Plots\Gage_3346000_scatter.png
# Scatter plot saved for Gage ID: 3347000 at Sanford_Scatter_Plots\Gage_3347000_scatter.png
# Scatter plot saved for Gage ID: 3350700 at Sanford_Scatter_Plots\Gage_3350700_scatter.png
# Scatter plot saved for Gage ID: 3351500 at Sanford_Scatter_Plots\Gage_3351500_scatter.png
# Scatter plot saved for Gage ID: 3353500 at Sanford_Scatter_Plots\Gage_3353500_scatter.png
# Scatter plot saved for Gage ID: 3357350 at Sanford_Scatter_Plots\Gage_3357350_scatter.png
# Scatter plot saved for Gage ID: 3358000 at Sanford_Scatter_Plots\Gage_3358000_scatter.png
# Scatter plot saved for Gage ID: 3361650 at Sanford_Scatter_Plots\Gage_3361650_scatter.png
# Scatter plot saved for Gage ID: 3361850 at Sanford_Scatter_Plots\Gage_3361850_scatter.png
# Scatter plot saved for Gage ID: 3362000 at Sanford_Scatter_Plots\Gage_3362000_scatter.png
# Scatter plot saved for Gage ID: 3363500 at Sanford_Scatter_Plots\Gage_3363500_scatter.png
# Scatter plot saved for Gage ID: 3364500 at Sanford_Scatter_Plots\Gage_3364500_scatter.png
# Scatter plot saved for Gage ID: 3366500 at Sanford_Scatter_Plots\Gage_3366500_scatter.png
# Scatter plot saved for Gage ID: 3368000 at Sanford_Scatter_Plots\Gage_3368000_scatter.png
# Scatter plot saved for Gage ID: 3369500 at Sanford_Scatter_Plots\Gage_3369500_scatter.png
# Scatter plot saved for Gage ID: 3375500 at Sanford_Scatter_Plots\Gage_3375500_scatter.png
# Scatter plot saved for Gage ID: 3378000 at Sanford_Scatter_Plots\Gage_3378000_scatter.png
# Scatter plot saved for Gage ID: 3378550 at Sanford_Scatter_Plots\Gage_3378550_scatter.png
# Scatter plot saved for Gage ID: 3378635 at Sanford_Scatter_Plots\Gage_3378635_scatter.png
# Scatter plot saved for Gage ID: 3382100 at Sanford_Scatter_Plots\Gage_3382100_scatter.png
# Scatter plot saved for Gage ID: 3384450 at Sanford_Scatter_Plots\Gage_3384450_scatter.png
# Scatter plot saved for Gage ID: 3438000 at Sanford_Scatter_Plots\Gage_3438000_scatter.png
# Scatter plot saved for Gage ID: 3439000 at Sanford_Scatter_Plots\Gage_3439000_scatter.png
# Scatter plot saved for Gage ID: 3446000 at Sanford_Scatter_Plots\Gage_3446000_scatter.png
# Scatter plot saved for Gage ID: 3451000 at Sanford_Scatter_Plots\Gage_3451000_scatter.png
# Scatter plot saved for Gage ID: 3455500 at Sanford_Scatter_Plots\Gage_3455500_scatter.png
# Scatter plot saved for Gage ID: 3456500 at Sanford_Scatter_Plots\Gage_3456500_scatter.png
# Scatter plot saved for Gage ID: 3459500 at Sanford_Scatter_Plots\Gage_3459500_scatter.png
# Scatter plot saved for Gage ID: 3460000 at Sanford_Scatter_Plots\Gage_3460000_scatter.png
# Scatter plot saved for Gage ID: 3463300 at Sanford_Scatter_Plots\Gage_3463300_scatter.png
# Scatter plot saved for Gage ID: 3471500 at Sanford_Scatter_Plots\Gage_3471500_scatter.png
# Scatter plot saved for Gage ID: 3473000 at Sanford_Scatter_Plots\Gage_3473000_scatter.png
# Scatter plot saved for Gage ID: 3479000 at Sanford_Scatter_Plots\Gage_3479000_scatter.png
# Scatter plot saved for Gage ID: 3488000 at Sanford_Scatter_Plots\Gage_3488000_scatter.png
# Scatter plot saved for Gage ID: 3491000 at Sanford_Scatter_Plots\Gage_3491000_scatter.png
# Scatter plot saved for Gage ID: 3498500 at Sanford_Scatter_Plots\Gage_3498500_scatter.png
# Scatter plot saved for Gage ID: 3500000 at Sanford_Scatter_Plots\Gage_3500000_scatter.png
# Scatter plot saved for Gage ID: 3500240 at Sanford_Scatter_Plots\Gage_3500240_scatter.png
# Scatter plot saved for Gage ID: 3504000 at Sanford_Scatter_Plots\Gage_3504000_scatter.png
# Scatter plot saved for Gage ID: 3512000 at Sanford_Scatter_Plots\Gage_3512000_scatter.png
# Scatter plot saved for Gage ID: 3531500 at Sanford_Scatter_Plots\Gage_3531500_scatter.png
# Scatter plot saved for Gage ID: 3550000 at Sanford_Scatter_Plots\Gage_3550000_scatter.png
# Scatter plot saved for Gage ID: 3574500 at Sanford_Scatter_Plots\Gage_3574500_scatter.png
# Scatter plot saved for Gage ID: 3592718 at Sanford_Scatter_Plots\Gage_3592718_scatter.png
# Scatter plot saved for Gage ID: 3604000 at Sanford_Scatter_Plots\Gage_3604000_scatter.png
# Scatter plot saved for Gage ID: 3612000 at Sanford_Scatter_Plots\Gage_3612000_scatter.png
# Scatter plot saved for Gage ID: 4015330 at Sanford_Scatter_Plots\Gage_4015330_scatter.png
# Scatter plot saved for Gage ID: 4024430 at Sanford_Scatter_Plots\Gage_4024430_scatter.png
# Scatter plot saved for Gage ID: 4027000 at Sanford_Scatter_Plots\Gage_4027000_scatter.png
# Scatter plot saved for Gage ID: 4027500 at Sanford_Scatter_Plots\Gage_4027500_scatter.png
# Scatter plot saved for Gage ID: 4036000 at Sanford_Scatter_Plots\Gage_4036000_scatter.png
# Scatter plot saved for Gage ID: 4037500 at Sanford_Scatter_Plots\Gage_4037500_scatter.png
# Scatter plot saved for Gage ID: 4040500 at Sanford_Scatter_Plots\Gage_4040500_scatter.png
# Scatter plot saved for Gage ID: 4043050 at Sanford_Scatter_Plots\Gage_4043050_scatter.png
# Scatter plot saved for Gage ID: 4045500 at Sanford_Scatter_Plots\Gage_4045500_scatter.png
# Scatter plot saved for Gage ID: 4056500 at Sanford_Scatter_Plots\Gage_4056500_scatter.png
# Scatter plot saved for Gage ID: 4057510 at Sanford_Scatter_Plots\Gage_4057510_scatter.png
# Scatter plot saved for Gage ID: 4057800 at Sanford_Scatter_Plots\Gage_4057800_scatter.png
# Scatter plot saved for Gage ID: 4059500 at Sanford_Scatter_Plots\Gage_4059500_scatter.png
# Scatter plot saved for Gage ID: 4063700 at Sanford_Scatter_Plots\Gage_4063700_scatter.png
# ...
# Scatter plot saved for Gage ID: 11152000 at Sanford_Scatter_Plots\Gage_11152000_scatter.png
# Scatter plot saved for Gage ID: 11156500 at Sanford_Scatter_Plots\Gage_11156500_scatter.png
# Scatter plot saved for Gage ID: 11160000 at Sanford_Scatter_Plots\Gage_11160000_scatter.png
# Scatter plot saved for Gage ID: 11160500 at Sanford_Scatter_Plots\Gage_11160500_scatter.png
# Scatter plot saved for Gage ID: 11162500 at Sanford_Scatter_Plots\Gage_11162500_scatter.png
# Scatter plot saved for Gage ID: 11176400 at Sanford_Scatter_Plots\Gage_11176400_scatter.png
# Scatter plot saved for Gage ID: 11176500 at Sanford_Scatter_Plots\Gage_11176500_scatter.png
# Scatter plot saved for Gage ID: 11180500 at Sanford_Scatter_Plots\Gage_11180500_scatter.png
# Scatter plot saved for Gage ID: 11200800 at Sanford_Scatter_Plots\Gage_11200800_scatter.png
# Scatter plot saved for Gage ID: 11224500 at Sanford_Scatter_Plots\Gage_11224500_scatter.png
# Scatter plot saved for Gage ID: 11230500 at Sanford_Scatter_Plots\Gage_11230500_scatter.png
# Scatter plot saved for Gage ID: 11237500 at Sanford_Scatter_Plots\Gage_11237500_scatter.png
# Scatter plot saved for Gage ID: 11253310 at Sanford_Scatter_Plots\Gage_11253310_scatter.png
# Scatter plot saved for Gage ID: 11264500 at Sanford_Scatter_Plots\Gage_11264500_scatter.png
# Scatter plot saved for Gage ID: 11266500 at Sanford_Scatter_Plots\Gage_11266500_scatter.png
# Scatter plot saved for Gage ID: 11274500 at Sanford_Scatter_Plots\Gage_11274500_scatter.png
# Scatter plot saved for Gage ID: 11274630 at Sanford_Scatter_Plots\Gage_11274630_scatter.png
# Scatter plot saved for Gage ID: 11284400 at Sanford_Scatter_Plots\Gage_11284400_scatter.png
# Scatter plot saved for Gage ID: 11299600 at Sanford_Scatter_Plots\Gage_11299600_scatter.png
# Scatter plot saved for Gage ID: 11345500 at Sanford_Scatter_Plots\Gage_11345500_scatter.png
# Scatter plot saved for Gage ID: 11376550 at Sanford_Scatter_Plots\Gage_11376550_scatter.png
# Scatter plot saved for Gage ID: 11379500 at Sanford_Scatter_Plots\Gage_11379500_scatter.png
# Scatter plot saved for Gage ID: 11381500 at Sanford_Scatter_Plots\Gage_11381500_scatter.png
# Scatter plot saved for Gage ID: 11383500 at Sanford_Scatter_Plots\Gage_11383500_scatter.png
# Scatter plot saved for Gage ID: 11390000 at Sanford_Scatter_Plots\Gage_11390000_scatter.png
# Scatter plot saved for Gage ID: 11402000 at Sanford_Scatter_Plots\Gage_11402000_scatter.png
# Scatter plot saved for Gage ID: 11413000 at Sanford_Scatter_Plots\Gage_11413000_scatter.png
# Scatter plot saved for Gage ID: 11424000 at Sanford_Scatter_Plots\Gage_11424000_scatter.png
# Scatter plot saved for Gage ID: 11427000 at Sanford_Scatter_Plots\Gage_11427000_scatter.png
# Scatter plot saved for Gage ID: 11451100 at Sanford_Scatter_Plots\Gage_11451100_scatter.png
# Scatter plot saved for Gage ID: 11458000 at Sanford_Scatter_Plots\Gage_11458000_scatter.png
# Scatter plot saved for Gage ID: 11461000 at Sanford_Scatter_Plots\Gage_11461000_scatter.png
# Scatter plot saved for Gage ID: 11468000 at Sanford_Scatter_Plots\Gage_11468000_scatter.png
# Scatter plot saved for Gage ID: 11468500 at Sanford_Scatter_Plots\Gage_11468500_scatter.png
# Scatter plot saved for Gage ID: 11473900 at Sanford_Scatter_Plots\Gage_11473900_scatter.png
# Scatter plot saved for Gage ID: 11475560 at Sanford_Scatter_Plots\Gage_11475560_scatter.png
# Scatter plot saved for Gage ID: 11476600 at Sanford_Scatter_Plots\Gage_11476600_scatter.png
# Scatter plot saved for Gage ID: 11478500 at Sanford_Scatter_Plots\Gage_11478500_scatter.png
# Scatter plot saved for Gage ID: 11480390 at Sanford_Scatter_Plots\Gage_11480390_scatter.png
# Scatter plot saved for Gage ID: 11481200 at Sanford_Scatter_Plots\Gage_11481200_scatter.png
# Scatter plot saved for Gage ID: 11482500 at Sanford_Scatter_Plots\Gage_11482500_scatter.png
# Scatter plot saved for Gage ID: 11521500 at Sanford_Scatter_Plots\Gage_11521500_scatter.png
# Scatter plot saved for Gage ID: 11522500 at Sanford_Scatter_Plots\Gage_11522500_scatter.png
# Scatter plot saved for Gage ID: 11523200 at Sanford_Scatter_Plots\Gage_11523200_scatter.png
# Scatter plot saved for Gage ID: 11528700 at Sanford_Scatter_Plots\Gage_11528700_scatter.png
# Scatter plot saved for Gage ID: 11532500 at Sanford_Scatter_Plots\Gage_11532500_scatter.png
# Scatter plot saved for Gage ID: 12013500 at Sanford_Scatter_Plots\Gage_12013500_scatter.png
# Scatter plot saved for Gage ID: 12020000 at Sanford_Scatter_Plots\Gage_12020000_scatter.png
# Scatter plot saved for Gage ID: 12025000 at Sanford_Scatter_Plots\Gage_12025000_scatter.png
# Scatter plot saved for Gage ID: 12025700 at Sanford_Scatter_Plots\Gage_12025700_scatter.png
# Scatter plot saved for Gage ID: 12035000 at Sanford_Scatter_Plots\Gage_12035000_scatter.png
# Scatter plot saved for Gage ID: 12036000 at Sanford_Scatter_Plots\Gage_12036000_scatter.png
# Scatter plot saved for Gage ID: 12040500 at Sanford_Scatter_Plots\Gage_12040500_scatter.png
# Scatter plot saved for Gage ID: 12041200 at Sanford_Scatter_Plots\Gage_12041200_scatter.png
# Scatter plot saved for Gage ID: 12043000 at Sanford_Scatter_Plots\Gage_12043000_scatter.png
# Scatter plot saved for Gage ID: 12048000 at Sanford_Scatter_Plots\Gage_12048000_scatter.png
# Scatter plot saved for Gage ID: 12054000 at Sanford_Scatter_Plots\Gage_12054000_scatter.png
# Scatter plot saved for Gage ID: 12056500 at Sanford_Scatter_Plots\Gage_12056500_scatter.png
# Scatter plot saved for Gage ID: 12073500 at Sanford_Scatter_Plots\Gage_12073500_scatter.png
# Scatter plot saved for Gage ID: 12082500 at Sanford_Scatter_Plots\Gage_12082500_scatter.png
# Scatter plot saved for Gage ID: 12086500 at Sanford_Scatter_Plots\Gage_12086500_scatter.png
# Scatter plot saved for Gage ID: 12092000 at Sanford_Scatter_Plots\Gage_12092000_scatter.png
# Scatter plot saved for Gage ID: 12093500 at Sanford_Scatter_Plots\Gage_12093500_scatter.png
# Scatter plot saved for Gage ID: 12095000 at Sanford_Scatter_Plots\Gage_12095000_scatter.png
# Scatter plot saved for Gage ID: 12112600 at Sanford_Scatter_Plots\Gage_12112600_scatter.png
# Scatter plot saved for Gage ID: 12114500 at Sanford_Scatter_Plots\Gage_12114500_scatter.png
# Scatter plot saved for Gage ID: 12115000 at Sanford_Scatter_Plots\Gage_12115000_scatter.png
# Scatter plot saved for Gage ID: 12115500 at Sanford_Scatter_Plots\Gage_12115500_scatter.png
# Scatter plot saved for Gage ID: 12117000 at Sanford_Scatter_Plots\Gage_12117000_scatter.png
# Scatter plot saved for Gage ID: 12141300 at Sanford_Scatter_Plots\Gage_12141300_scatter.png
# Scatter plot saved for Gage ID: 12142000 at Sanford_Scatter_Plots\Gage_12142000_scatter.png
# Scatter plot saved for Gage ID: 12143600 at Sanford_Scatter_Plots\Gage_12143600_scatter.png
# Scatter plot saved for Gage ID: 12144000 at Sanford_Scatter_Plots\Gage_12144000_scatter.png
# Scatter plot saved for Gage ID: 12144500 at Sanford_Scatter_Plots\Gage_12144500_scatter.png
# Scatter plot saved for Gage ID: 12145500 at Sanford_Scatter_Plots\Gage_12145500_scatter.png
# Scatter plot saved for Gage ID: 12147500 at Sanford_Scatter_Plots\Gage_12147500_scatter.png
# Scatter plot saved for Gage ID: 12147600 at Sanford_Scatter_Plots\Gage_12147600_scatter.png
# Scatter plot saved for Gage ID: 12148500 at Sanford_Scatter_Plots\Gage_12148500_scatter.png
# Scatter plot saved for Gage ID: 12167000 at Sanford_Scatter_Plots\Gage_12167000_scatter.png
# Scatter plot saved for Gage ID: 12175500 at Sanford_Scatter_Plots\Gage_12175500_scatter.png
# Scatter plot saved for Gage ID: 12178100 at Sanford_Scatter_Plots\Gage_12178100_scatter.png
# Scatter plot saved for Gage ID: 12186000 at Sanford_Scatter_Plots\Gage_12186000_scatter.png
# Scatter plot saved for Gage ID: 12189500 at Sanford_Scatter_Plots\Gage_12189500_scatter.png
# Scatter plot saved for Gage ID: 12332000 at Sanford_Scatter_Plots\Gage_12332000_scatter.png
# Scatter plot saved for Gage ID: 12335500 at Sanford_Scatter_Plots\Gage_12335500_scatter.png
# Scatter plot saved for Gage ID: 12342500 at Sanford_Scatter_Plots\Gage_12342500_scatter.png
# Scatter plot saved for Gage ID: 12358500 at Sanford_Scatter_Plots\Gage_12358500_scatter.png
# Scatter plot saved for Gage ID: 12374250 at Sanford_Scatter_Plots\Gage_12374250_scatter.png
# Scatter plot saved for Gage ID: 12375900 at Sanford_Scatter_Plots\Gage_12375900_scatter.png
# Scatter plot saved for Gage ID: 12377150 at Sanford_Scatter_Plots\Gage_12377150_scatter.png
# Scatter plot saved for Gage ID: 12381400 at Sanford_Scatter_Plots\Gage_12381400_scatter.png
# Scatter plot saved for Gage ID: 12383500 at Sanford_Scatter_Plots\Gage_12383500_scatter.png
# Scatter plot saved for Gage ID: 12388400 at Sanford_Scatter_Plots\Gage_12388400_scatter.png
# Scatter plot saved for Gage ID: 12390700 at Sanford_Scatter_Plots\Gage_12390700_scatter.png
# Scatter plot saved for Gage ID: 12411000 at Sanford_Scatter_Plots\Gage_12411000_scatter.png
# Scatter plot saved for Gage ID: 12414500 at Sanford_Scatter_Plots\Gage_12414500_scatter.png
# Scatter plot saved for Gage ID: 12414900 at Sanford_Scatter_Plots\Gage_12414900_scatter.png
# Scatter plot saved for Gage ID: 12447390 at Sanford_Scatter_Plots\Gage_12447390_scatter.png
# Scatter plot saved for Gage ID: 12451000 at Sanford_Scatter_Plots\Gage_12451000_scatter.png
# Scatter plot saved for Gage ID: 12452800 at Sanford_Scatter_Plots\Gage_12452800_scatter.png
# Scatter plot saved for Gage ID: 12488500 at Sanford_Scatter_Plots\Gage_12488500_scatter.png
# Scatter plot saved for Gage ID: 12502500 at Sanford_Scatter_Plots\Gage_12502500_scatter.png
# Scatter plot saved for Gage ID: 13011500 at Sanford_Scatter_Plots\Gage_13011500_scatter.png
# Scatter plot saved for Gage ID: 13011900 at Sanford_Scatter_Plots\Gage_13011900_scatter.png
# Scatter plot saved for Gage ID: 13018300 at Sanford_Scatter_Plots\Gage_13018300_scatter.png
# Scatter plot saved for Gage ID: 13023000 at Sanford_Scatter_Plots\Gage_13023000_scatter.png
# Scatter plot saved for Gage ID: 13052200 at Sanford_Scatter_Plots\Gage_13052200_scatter.png
# Scatter plot saved for Gage ID: 13075000 at Sanford_Scatter_Plots\Gage_13075000_scatter.png
# Scatter plot saved for Gage ID: 13083000 at Sanford_Scatter_Plots\Gage_13083000_scatter.png
# Scatter plot saved for Gage ID: 13120000 at Sanford_Scatter_Plots\Gage_13120000_scatter.png
# Scatter plot saved for Gage ID: 13161500 at Sanford_Scatter_Plots\Gage_13161500_scatter.png
# Scatter plot saved for Gage ID: 13174500 at Sanford_Scatter_Plots\Gage_13174500_scatter.png
# Scatter plot saved for Gage ID: 13200000 at Sanford_Scatter_Plots\Gage_13200000_scatter.png
# Scatter plot saved for Gage ID: 13235000 at Sanford_Scatter_Plots\Gage_13235000_scatter.png
# Scatter plot saved for Gage ID: 13239000 at Sanford_Scatter_Plots\Gage_13239000_scatter.png
# Scatter plot saved for Gage ID: 13240000 at Sanford_Scatter_Plots\Gage_13240000_scatter.png
# Scatter plot saved for Gage ID: 13310700 at Sanford_Scatter_Plots\Gage_13310700_scatter.png
# Scatter plot saved for Gage ID: 13313000 at Sanford_Scatter_Plots\Gage_13313000_scatter.png
# Scatter plot saved for Gage ID: 13331500 at Sanford_Scatter_Plots\Gage_13331500_scatter.png
# Scatter plot saved for Gage ID: 13337000 at Sanford_Scatter_Plots\Gage_13337000_scatter.png
# Scatter plot saved for Gage ID: 13338500 at Sanford_Scatter_Plots\Gage_13338500_scatter.png
# Scatter plot saved for Gage ID: 13340000 at Sanford_Scatter_Plots\Gage_13340000_scatter.png
# Scatter plot saved for Gage ID: 13340600 at Sanford_Scatter_Plots\Gage_13340600_scatter.png
# Scatter plot saved for Gage ID: 13345000 at Sanford_Scatter_Plots\Gage_13345000_scatter.png
# Scatter plot saved for Gage ID: 14020000 at Sanford_Scatter_Plots\Gage_14020000_scatter.png
# Scatter plot saved for Gage ID: 14034500 at Sanford_Scatter_Plots\Gage_14034500_scatter.png
# Scatter plot saved for Gage ID: 14092750 at Sanford_Scatter_Plots\Gage_14092750_scatter.png
# Scatter plot saved for Gage ID: 14096850 at Sanford_Scatter_Plots\Gage_14096850_scatter.png
# Scatter plot saved for Gage ID: 14123500 at Sanford_Scatter_Plots\Gage_14123500_scatter.png
# Scatter plot saved for Gage ID: 14137000 at Sanford_Scatter_Plots\Gage_14137000_scatter.png
# Scatter plot saved for Gage ID: 14138800 at Sanford_Scatter_Plots\Gage_14138800_scatter.png
# Scatter plot saved for Gage ID: 14138900 at Sanford_Scatter_Plots\Gage_14138900_scatter.png
# Scatter plot saved for Gage ID: 14139800 at Sanford_Scatter_Plots\Gage_14139800_scatter.png
# Scatter plot saved for Gage ID: 14141500 at Sanford_Scatter_Plots\Gage_14141500_scatter.png
# Scatter plot saved for Gage ID: 14145500 at Sanford_Scatter_Plots\Gage_14145500_scatter.png
# Scatter plot saved for Gage ID: 14151000 at Sanford_Scatter_Plots\Gage_14151000_scatter.png
# Scatter plot saved for Gage ID: 14154500 at Sanford_Scatter_Plots\Gage_14154500_scatter.png
# Scatter plot saved for Gage ID: 14155500 at Sanford_Scatter_Plots\Gage_14155500_scatter.png
# Scatter plot saved for Gage ID: 14158500 at Sanford_Scatter_Plots\Gage_14158500_scatter.png
# Scatter plot saved for Gage ID: 14158790 at Sanford_Scatter_Plots\Gage_14158790_scatter.png
# Scatter plot saved for Gage ID: 14159500 at Sanford_Scatter_Plots\Gage_14159500_scatter.png
# Scatter plot saved for Gage ID: 14162200 at Sanford_Scatter_Plots\Gage_14162200_scatter.png
# Scatter plot saved for Gage ID: 14165000 at Sanford_Scatter_Plots\Gage_14165000_scatter.png
# Scatter plot saved for Gage ID: 14166500 at Sanford_Scatter_Plots\Gage_14166500_scatter.png
# Scatter plot saved for Gage ID: 14170000 at Sanford_Scatter_Plots\Gage_14170000_scatter.png
# Scatter plot saved for Gage ID: 14178000 at Sanford_Scatter_Plots\Gage_14178000_scatter.png
# Scatter plot saved for Gage ID: 14182500 at Sanford_Scatter_Plots\Gage_14182500_scatter.png
# Scatter plot saved for Gage ID: 14185000 at Sanford_Scatter_Plots\Gage_14185000_scatter.png
# Scatter plot saved for Gage ID: 14185900 at Sanford_Scatter_Plots\Gage_14185900_scatter.png
# Scatter plot saved for Gage ID: 14187000 at Sanford_Scatter_Plots\Gage_14187000_scatter.png
# Scatter plot saved for Gage ID: 14190500 at Sanford_Scatter_Plots\Gage_14190500_scatter.png
# Scatter plot saved for Gage ID: 14203500 at Sanford_Scatter_Plots\Gage_14203500_scatter.png
# Scatter plot saved for Gage ID: 14216500 at Sanford_Scatter_Plots\Gage_14216500_scatter.png
# Scatter plot saved for Gage ID: 14222500 at Sanford_Scatter_Plots\Gage_14222500_scatter.png
# Scatter plot saved for Gage ID: 14226500 at Sanford_Scatter_Plots\Gage_14226500_scatter.png
# Scatter plot saved for Gage ID: 14236200 at Sanford_Scatter_Plots\Gage_14236200_scatter.png
# Scatter plot saved for Gage ID: 14301000 at Sanford_Scatter_Plots\Gage_14301000_scatter.png
# Scatter plot saved for Gage ID: 14301500 at Sanford_Scatter_Plots\Gage_14301500_scatter.png
# Scatter plot saved for Gage ID: 14303200 at Sanford_Scatter_Plots\Gage_14303200_scatter.png
# Scatter plot saved for Gage ID: 14305500 at Sanford_Scatter_Plots\Gage_14305500_scatter.png
# Scatter plot saved for Gage ID: 14306340 at Sanford_Scatter_Plots\Gage_14306340_scatter.png
# Scatter plot saved for Gage ID: 14306500 at Sanford_Scatter_Plots\Gage_14306500_scatter.png
# Scatter plot saved for Gage ID: 14308990 at Sanford_Scatter_Plots\Gage_14308990_scatter.png
# Scatter plot saved for Gage ID: 14309000 at Sanford_Scatter_Plots\Gage_14309000_scatter.png
# Scatter plot saved for Gage ID: 14309500 at Sanford_Scatter_Plots\Gage_14309500_scatter.png
# Scatter plot saved for Gage ID: 14316700 at Sanford_Scatter_Plots\Gage_14316700_scatter.png
# Scatter plot saved for Gage ID: 14325000 at Sanford_Scatter_Plots\Gage_14325000_scatter.png
# Scatter plot saved for Gage ID: 14337500 at Sanford_Scatter_Plots\Gage_14337500_scatter.png
# Scatter plot saved for Gage ID: 14338000 at Sanford_Scatter_Plots\Gage_14338000_scatter.png
# Scatter plot saved for Gage ID: 14362000 at Sanford_Scatter_Plots\Gage_14362000_scatter.png
# Scatter plot saved for Gage ID: 14362250 at Sanford_Scatter_Plots\Gage_14362250_scatter.png
# Scatter plot saved for Gage ID: 14377100 at Sanford_Scatter_Plots\Gage_14377100_scatter.png
# Scatter plot saved for Gage ID: 14400000 at Sanford_Scatter_Plots\Gage_14400000_scatter.png
# ✅ Scatter plots generated and saved in: Sanford_Scatter_Plots

# %%
# Convert Regression Results to DataFrame and save
scatter_results = []
for gage_id, group in aligned_data.groupby("name"):
    X = group.filter(like="Sanford_").values.flatten().reshape(-1, 1)
    Y = group.filter(like="CONUS404_").values.flatten()

    if len(X) > 1:  # Ensure enough data points
        model = LinearRegression()
        model.fit(X, Y)
        r_squared = model.score(X, Y)
        slope = model.coef_[0]

        # Store Regression Results
        scatter_results.append({
            "Gage_ID": gage_id,
            "R_Squared": r_squared,
            "Slope": slope,
            "Intercept": model.intercept_
        })

# Save Regression Results to CSV
scatter_results_df = pd.DataFrame(scatter_results)
scatter_results_df.to_csv("Scatter_Regression_Results.csv", index=False)

# Display results
display(scatter_results_df.head())

print("✅ Regression results saved as AET_Scatter_Regression_Results.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Gage_ID  R_Squared     Slope   Intercept
# 0  1013500   0.052510 -0.190895  595.843329
# 1  1019000   0.185523  0.245014  331.400412
# 2  1022500   0.089416  0.158771  429.035394
# 3  1030500   0.010477  0.072099  484.373715
# 4  1031500   0.053024  0.133807  448.291064
# ✅ Regression results saved as AET_Scatter_Regression_Results.csv

# %%
import pandas as pd

# File paths
sanford_file = r"C:\Users\adi10136\OneDrive - Iowa State University\Desktop\CONUS404\ET Sanford\ET_Mean_Sanford_Agreed_Basins\AET_Basins_Mean_Values.csv"
conus404_file = r"C:\Users\adi10136\OneDrive - Iowa State University\Desktop\CONUS404\ET_WaterYears\AET_mean_Basins_CONUS404\ET_Basins_Mean_Values.csv"

# Load the CSV files
sanford_df = pd.read_csv(sanford_file)
conus404_df = pd.read_csv(conus404_file)

# Merge the DataFrames on Gage_ID (OBJECTID or other unique field)
aligned_data = pd.merge(
    sanford_df,
    conus404_df,
    on="name",  # Change this if a different ID field is needed
    how="inner"
)

# Rename columns for clarity
aligned_data.rename(columns=lambda x: x.replace("AET_", "Sanford_").replace("ET_", "CONUS404_"), inplace=True)

# Drop rows with NaN values
aligned_data = aligned_data.dropna()

# Display first few rows
display(aligned_data.head())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       name  Sanford_1990  Sanford_1991  Sanford_1992  Sanford_1993  \
# 0  1013500    532.240341    507.776588    535.722459    539.077791
# 1  1019000    567.941718    582.810206    511.858339    486.392273
# 2  1022500    569.082703    594.823793    492.098908    469.906591
# 3  1030500    567.746502    532.820693    500.170837    510.349288
# 4  1031500    579.718110    555.205357    499.591072    510.097644
#
#    Sanford_1994  Sanford_1995  Sanford_1996  Sanford_1997  Sanford_1998  ...  \
# 0    565.502197    482.285055    566.518196    523.279233    563.964709  ...
# 1    502.745313    517.294172    550.425525    542.522675    534.586589  ...
# 2    509.816766    511.827485    546.341557    520.660206    522.562560  ...
# 3    524.644646    484.188340    566.161814    533.798302    547.532335  ...
# 4    548.800909    465.343476    571.734233    534.114904    578.778529  ...
#
#    CONUS404_2000  CONUS404_2001  CONUS404_2002  CONUS404_2003  CONUS404_2004  \
# 0     477.541695     521.729294     502.856030     471.002144     485.324483
# 1     460.994583     448.315687     476.387563     448.358631     448.451536
# 2     504.111010     518.397766     536.849804     502.146776     492.854907
# 3     508.964262     534.171812     545.085634     500.798790     510.233407
# 4     509.612876     532.145247     548.136173     497.905593     502.271921
#
#    CONUS404_2005  CONUS404_2006  CONUS404_2007  CONUS404_2008  CONUS404_2009
# 0     507.062311     521.457250     490.907687     480.312386     457.177166
# 1     479.129280     496.595954     464.294189     445.773821     441.038802
# 2     517.617510     532.765595     519.859560     500.135492     476.573745
# 3     542.172768     548.714729     517.182321     497.271122     492.144484
# 4     536.402295     540.497048     512.987179     509.845377     481.151956
#
# [5 rows x 41 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Function to create scatter plots with linear regression for a single gage
def plot_scatter_with_regression(data, gage_id):
    """Generates regression results for a specific gage ID."""
    gage_data = data[data["name"] == gage_id]

    # Extract X (Sanford AET) and Y (CONUS404 AET)
    X = gage_data.filter(like="Sanford_").values.flatten().reshape(-1, 1)
    Y = gage_data.filter(like="CONUS404_").values.flatten()

    if len(X) > 1:  # Ensure enough data points
        model = LinearRegression()
        model.fit(X, Y)
        Y_pred = model.predict(X)
        r_squared = model.score(X, Y)
        return gage_id, X, Y, Y_pred, r_squared, model, len(X)
    
    return None

# Function to create a grid layout of scatter plots with filtering
def plot_scatter_grid(data, scatter_width=4, scatter_height=3, output_file="scatter_grid_poster.png"):
    """Creates a grid of scatter plots for gages with R² > 0.7 and > 15 data points."""
    filtered_gages = []
    results = []

    for gage_id in data["name"].unique():
        result = plot_scatter_with_regression(data, gage_id)
        if result:
            gage_id, X, Y, Y_pred, r_squared, model, num_points = result
            if r_squared > 0.70 and num_points > 15:  # Apply both filters
                filtered_gages.append(gage_id)
                results.append((X, Y, Y_pred, r_squared, gage_id, model))

    # Determine the number of rows and columns for the grid
    n = len(filtered_gages)
    cols = 4  # Adjust as needed for layout
    rows = (n + cols - 1) // cols  # Calculate number of rows

    # Set figure size based on scatter plot dimensions
    fig, axes = plt.subplots(rows, cols, figsize=(scatter_width * cols, scatter_height * rows))
    axes = axes.flatten() if n > 1 else [axes]

    for i, (X, Y, Y_pred, r_squared, gage_id, model) in enumerate(results):
        ax = axes[i]
        ax.scatter(X, Y, color="black", alpha=0.7, s=9, label="Data points")
        ax.plot(X, Y_pred, color="blue", label=f"Fit: y={model.coef_[0]:.2f}x+{model.intercept_:.2f}")
        ax.plot([min(X), max(X)], [min(X), max(X)], linestyle="--", color="gray", label="1:1 Line")
        ax.set_title(f"Gage: {gage_id}\nR² = {r_squared:.2f}", fontsize=18)
        ax.set_xlabel("Sanford AET (mm)", fontsize=16)
        ax.set_ylabel("CONUS404 AET (mm)", fontsize=16)
        ax.tick_params(axis="y", which="major", labelsize=14)
        ax.tick_params(axis="x", which="major", labelsize=14)
        ax.legend(fontsize=12, loc="lower right")

    # Hide unused subplots if any
    for j in range(len(results), len(axes)):
        axes[j].axis("off")

    # Adjust layout for presentation
    plt.tight_layout(pad=2.0)
    plt.savefig(output_file, dpi=600)
    plt.close()

    print(f"Scatter grid saved to {output_file}")

# Generate the scatter plot grid for gages with R² > 0.7
plot_scatter_grid(aligned_data, scatter_width=5, scatter_height=4, output_file="AET_CONUS404_gages_SP.png")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Scatter grid saved to AET_CONUS404_gages_SP.png
